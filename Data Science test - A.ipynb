# %% [markdown]
# The goal of this exercise is to predict vehicle sale prices (Sold_Amount). Prepare a report documenting your thought
# process in building out the prediction model. The process should display some of the following considerations:
#
#     • Data understanding, including highlighting errors and concerns with the data.
#     • Features to select and/or engineer. Take note that you cannot use the following fields:
#       AvgWholesale, AvgRetail, GoodWholesale, GoodRetail, TradeMin, TradeMax, PrivateMax
#     • Experimentation with various feature encoding and modeling techniques.
#     • Report model performance on test dataset and do not drop any rows in the test dataset.
#     • Different ways of evaluating the performance of the model and diagnosing the model for areas where it
#       may be underperforming.
#
# You can use Jupyter Notebooks for the report, but feel free to experiment with different Python libraries apart from
# the generic Scikit-learn and scientific libraries. For the sake of managing your experiments, feel free to play with
# tools like MLFlow. If you wish to focus the exercise more on engineering and deploying the model, you can keep
# the modeling process basic but demonstrate the use of tools like Seldon and Kubeflow for training and
# productionizing models.
#
# Please place all code and logs in a .git repository with README files for executing the code or any demo if
# necessary.

# %%
##import necessary library
import pandas as pd
from operator import itemgetter
import missingno as msno
import numpy as np
from sklearn.impute import SimpleImputer
from pickle import dump, load
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.metrics import accuracy_score, precision_score, recall_score, explained_variance_score, r2_score
from sklearn.svm import SVR
import mlflow
import mlflow.sklearn
from mlflow.models.signature import infer_signature
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ### Set mlflow
# Resource: https://github.com/mtpatter/mlflow-tutorial/blob/main/mlflow-sklearn.ipynb
#
# #### You need to start mlflow server first  via cmd with this command
# <i>mlflow server --backend-store-uri sqlite:///mlflow.db --default-artifact-root ./artifacts --host 127.0.0.1:5000</i>

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("my-experiment")
# Out:
# <Experiment: artifact_location='./artifacts/1', creation_time=1666370316988, experiment_id='1', last_update_time=1666370316988, lifecycle_stage='active', name='my-experiment', tags={}>

# %%
from mlflow.tracking import MlflowClient
client = MlflowClient()

# %% [markdown]
# ### Read datasets

# %%
pd.set_option("display.max_columns", None)

# %%
##Read train and test data

train_dat = pd.read_csv('DatiumTrain.rpt', delimiter='\t')
test_dat = pd.read_csv('DatiumTest.rpt', delimiter='\t')
# Out:
# C:\Users\faizm\.conda\envs\datium\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (27,94) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\faizm\.conda\envs\datium\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (27,91) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
train_dat.describe()
# Out:
#           YearGroup    MonthGroup   SequenceNum       GearNum       DoorNum  \
# count  50704.000000  50704.000000  50704.000000  50703.000000  50704.000000
# mean    2005.177777      1.480396      9.632869      4.615447      4.124467
# std        5.302207      2.997782     11.171761      0.956656      0.868757
# min     1968.000000      0.000000      0.000000      1.000000      2.000000
# 25%     2001.000000      0.000000      1.000000      4.000000      4.000000
# 50%     2006.000000      0.000000      6.000000      4.000000      4.000000
# 75%     2009.000000      1.000000     15.000000      5.000000      5.000000
# max     2016.000000     12.000000    120.000000      9.000000      5.000000
#
#          EngineSize     Cylinders  FuelCapacity  GrossCombinationMAss  \
# count  50704.000000  50704.000000  49892.000000          24524.000000
# mean    3000.569580      5.061731     71.905035           4237.271489
# std      931.057061      1.123823     22.131647           1090.250085
# min      659.000000      2.000000     32.000000           1450.000000
# 25%     2359.000000      4.000000     63.000000           3310.000000
# 50%     2982.000000      5.000000     70.000000           4140.000000
# 75%     3791.000000      6.000000     75.000000           4900.000000
# max     7300.000000     12.000000    180.000000           9071.000000
#
# 75%              6.000000         12.000000        6.500000   650.000000
# max             24.000000         24.000000        6.500000   650.000000
#
#        AltEngPower  AltEngPowerFrom  AltEngPowerTo  AltEngTorque  \
# count   836.000000       156.000000     237.000000    785.000000
# mean     82.557895      1193.333333    5268.270042    280.834395
# std      30.820288        41.228448    5513.802631     72.269200
# min      10.000000       940.000000    1500.000000     78.000000
# 25%      50.000000      1200.000000    1540.000000    270.000000
# 50%     105.000000      1200.000000    1540.000000    270.000000
# 75%     105.000000      1200.000000   13500.000000    270.000000
# max     165.000000      1200.000000   13500.000000    400.000000
#
#        AltEngTorqueFrom  AltEngTorqueTo  NormalChargeMins  QuickChargeMins  \
# count               0.0       164.00000               0.0              0.0
# mean                NaN      1193.04878               NaN              NaN
# std                 NaN        67.03518               NaN              NaN
# min                 NaN       940.00000               NaN              NaN
# 25%                 NaN      1200.00000               NaN              NaN
# 50%                 NaN      1200.00000               NaN              NaN
# 75%                 NaN      1200.00000               NaN              NaN
# max                 NaN      1500.00000               NaN              NaN
#
#        NormalChargeVoltage  QuickChargeVoltage  KMRangeElectricEng  \
# count                  0.0                 0.0                 2.0
# mean                   NaN                 NaN                37.0
# std                    NaN                 NaN                 0.0
# min                    NaN                 NaN                37.0
# 25%                    NaN                 NaN                37.0
# 50%                    NaN                 NaN                37.0
# 75%                    NaN                 NaN                37.0
# max                    NaN                 NaN                37.0
#
#        TopSpeedElectricEng  GreenhouseRating  AirpollutionRating  \
# count                  2.0      24644.000000        24630.000000
# mean                 120.0          5.701530            5.819610
# std                    0.0          1.128458            1.824878
# min                  120.0          1.500000            0.500000
# 25%                  120.0          5.000000            5.000000
# 50%                  120.0          5.500000            6.500000
# 75%                  120.0          6.500000            6.500000
# max                  120.0          9.000000            9.000000
#
#        OverallGreenStarRating   CO2Combined      CO2Urban  CO2ExtraUrban  \
# count            24821.000000  33730.000000  12112.000000   12110.000000
# mean                 3.323819    232.896294    283.967801     171.276879
# std                  0.724334     49.219886     63.595995      34.881419
# min                  0.500000     89.000000     86.000000      86.000000
# 25%                  3.000000    199.000000    250.000000     143.000000
# 50%                  3.500000    234.000000    291.000000     172.000000
# 75%                  3.500000    266.000000    329.000000     195.000000
# max                  5.000000    463.000000    602.000000     300.000000
#
#           FuelUrban  FuelExtraurban  FuelCombined   AncapRating     AverageKM  \
# count  29394.000000    28241.000000  46346.000000  25965.000000  50703.000000
# mean      11.587654        7.170908      9.476818      4.260312    306.617163
# std        2.642395        1.392198      2.102242      0.654834    139.121984
# min        3.700000        3.700000      3.900000      1.000000     35.000000
# 25%       10.200000        6.500000      8.200000      4.000000    200.000000
# 50%       11.500000        7.000000      9.200000      4.000000    275.000000
# 75%       12.500000        7.800000     10.900000      5.000000    400.000000
# max       29.100000       16.000000     19.500000      5.000000   1170.000000
#
#              GoodKM   AvgWholesale      AvgRetail  GoodWholesale  \
# count  50703.000000   37594.000000   45973.000000   43951.000000
# mean     188.857168    7518.701123    8928.714680    8223.517099
# std       88.032477    7092.971211    7873.691056    7556.364122
# min       20.000000     600.000000    1500.000000     800.000000
# 25%      120.000000    2900.000000    3800.000000    3150.000000
# 50%      180.000000    5850.000000    7000.000000    6400.000000
# 75%      240.000000    9900.000000   11650.000000   10900.000000
# max      780.000000  283200.000000  357250.000000  336700.000000
#
#           GoodRetail       TradeMin       TradeMax     PrivateMax  \
# count   50703.000000   37594.000000   37594.000000   50703.000000
# mean    10038.255133    6556.740437    8468.244933    9018.105438
# std      8454.463138    6474.531721    7049.352627    7709.541957
# min       750.000000     300.000000    1800.000000     700.000000
# 25%      4500.000000    2400.000000    4100.000000    4000.000000
# 50%      8000.000000    5100.000000    6800.000000    7100.000000
# 75%     13000.000000    8700.000000   10700.000000   11700.000000
# max    427500.000000  261400.000000  319900.000000  363900.000000
#
#             NewPrice  Age_Comp_Months            KM    Sold_Amount
# count   50703.000000     50659.000000  5.070200e+04   50700.000000
# mean    36726.014555        45.775223  8.495406e+04   16401.722226
# std     15522.567237        32.153830  7.283732e+04   10312.029249
# min      5157.000000         0.000000  0.000000e+00       0.000000
# 25%     29500.000000        26.000000  4.085400e+04   10500.000000
# 50%     34990.000000        38.000000  6.846900e+04   15000.000000
# 75%     41260.000000        54.000000  1.165400e+05   20425.000000
# max    525000.000000      1279.000000  8.883234e+06  317000.000000

# %%
train_dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50704 entries, 0 to 50703
# Columns: 130 entries, Make to Sold_Amount
# dtypes: float64(65), int64(6), object(59)
# memory usage: 50.3+ MB

# %% [markdown]
# ## Training set data preprocessing steps
#
# Step 1 - Check if there is any missing value NaN for every columns. Thnink the strategies on dealing with it
#
# Step 2 - Drop columns that have almost similar value or uniques (e.g.Make, Model and MakeCode, FamilyCode).
#
# Step 3 - Machine learning cant process string. Convert the string to numeric value.
#
# Resource: https://www.analyticsvidhya.com/blog/2021/10/how-to-deal-with-missing-data-using-python/#:~:text=Pairwise%20Deletion%20is%20used%20if,like%20mean%2C%20sum%2C%20etc.

# %% [markdown]
# #### Step 1: Missing values

# %%
#this fucntion to check any NaN values and delete the row
def check_delete_row(dat, colname=[]):
    count = {}
    h = 0
    if colname:
        for i, c in enumerate(colname):
            n = dat[c].isna().sum()
            count.update({c:n})
            if n != 0:
                h += 1
        high = dict(sorted(count.items(), key = itemgetter(1), reverse = True)[:len(colname)])
        print("Column with highest to lowest NaN: {}".format(high))
    else:
        for i, c in enumerate(dat.columns):
            n = dat[c].isna().sum()
            count.update({c:n})
            if n != 0:
                h += 1
    
        # find top N highest and lowest columns with NaN values
        high = dict(sorted(count.items(), key = itemgetter(1), reverse = True)[:5])
        low = dict(sorted(count.items(), key = itemgetter(1), reverse = False)[:5])
        print("Number of columns: {}".format(len(dat.axes[1])))
        print("Number of rows: {}".format(len(dat.axes[0])))
        print("Total columns have NaN value: {}".format(h))
        print("Column with highest NaN: {}".format(high))
        print("Column with lowest NaN: {}".format(low))
        print("Total missing values: {}".format(dat.isna().sum().sum()))
        
        
    return count, dat

# %%
count, _ = check_delete_row(train_dat)
# Out:
# Number of columns: 130
# Number of rows: 50704
# Total columns have NaN value: 105
# Column with highest NaN: {'AltEngTorqueFrom': 50704, 'NormalChargeMins': 50704, 'QuickChargeMins': 50704, 'NormalChargeVoltage': 50704, 'QuickChargeVoltage': 50704}
# Column with lowest NaN: {'Make': 0, 'Model': 0, 'MakeCode': 0, 'FamilyCode': 0, 'YearGroup': 0}
# Total missing values: 2087062

# %%
#Check columns with missing values
sorted(count.items(), key = itemgetter(1), reverse = True)
# Out:
# [('AltEngTorqueFrom', 50704),
#  ('NormalChargeMins', 50704),
#  ('QuickChargeMins', 50704),
#  ('NormalChargeVoltage', 50704),
#  ('QuickChargeVoltage', 50704),
#  ('KMRangeElectricEng', 50702),
#  ('TopSpeedElectricEng', 50702),
#  ('AltEngAmpHours', 50698),
#  ('ElectricEngineLocation', 50678),
#  ('FreeScheduledService', 50608),
#  ('AltEngPowerFrom', 50548),
#  ('AltEngTorqueTo', 50540),
#  ('PowerRPMFrom', 50495),
#  ('AltEngPowerTo', 50467),
#  ('Roofline', 50184),
#  ('AltEngTorque', 49919),
#  ('AltEngDrive', 49869),
#  ('AltEngVolts', 49868),
#  ('AltEngPower', 49868),
#  ('AltEngEngineType', 49866),
#  ('AltEngBatteryType', 49866),
#  ('AltEngCurrentType', 49866),
#  ('AltEngChargingMethod', 49866),
#  ('WheelBaseConfig', 48905),
#  ('MaxEthanolBlend', 48554),
#  ('BadgeSecondaryDescription', 48271),
#  ('ExtraIdentification', 47447),
#  ('TorqueRPMFrom', 46005),
#  ('BodyConfigDescription', 42021),
#  ('EmissionStandard', 41755),
#  ('CO2ExtraUrban', 38594),
#  ('CO2Urban', 38592),
#  ('Acceleration', 35574),
#  ('SeriesModelYear', 35164),
#  ('WarrantyCustAssist', 27949),
#  ('GrossCombinationMAss', 26180),
#  ('AirpollutionRating', 26074),
#  ('GreenhouseRating', 26060),
#  ('OverallGreenStarRating', 25883),
#  ('PayLoad', 25089),
#  ('AncapRating', 24739),
#  ('FirstServiceMonths', 22813),
#  ('FuelExtraurban', 22463),
#  ('FuelUrban', 21310),
#  ('GrossVehicleMass', 20241),
#  ('FirstServiceKM', 19972),
#  ('RegServiceMonths', 19958),
#  ('CO2Combined', 16974),
#  ('AvgWholesale', 13110),
#  ('TradeMin', 13110),
#  ('TradeMax', 13110),
#  ('RonRating', 10967),
#  ('TareMass', 10551),
#  ('ModelCode', 10430),
#  ('VFactsPrice', 10381),
#  ('GoodWholesale', 6753),
#  ('BadgeDescription', 6605),
#  ('TowingNoBrakes', 5200),
#  ('AvgRetail', 4731),
#  ('FuelCombined', 4358),
#  ('WarrantyKM', 2965),
#  ('TowingBrakes', 2944),
#  ('WarrantyYears', 2614),
#  ('EngineConfigurationDescription', 1860),
#  ('KerbWeight', 1534),
#  ('FrontTyreSize', 904),
#  ('RearTyreSize', 904),
#  ('Series', 851),
#  ('FuelCapacity', 812),
#  ('EngineNum', 804),
#  ('FrontRimDesc', 726),
#  ('RearRimDesc', 726),
#  ('Height', 719),
#  ('Length', 659),
#  ('Width', 657),
#  ('VIN', 578),
#  ('ValvesCylinder', 510),
#  ('VFactsClass', 428),
#  ('VFactsSegment', 428),
#  ('TorqueRPMTo', 308),
#  ('Torque', 273),
#  ('CamDescription', 218),
#  ('WheelBase', 143),
#  ('PowerRPMTo', 138),
#  ('Power', 112),
#  ('Compliance_Date', 45),
#  ('Age_Comp_Months', 45),
#  ('Colour', 44),
#  ('SeatCapacity', 37),
#  ('MethodOfDeliveryDescription', 22),
#  ('EngineLocation', 13),
#  ('Sold_Amount', 4),
#  ('KM', 2),
#  ('GearNum', 1),
#  ('BuildCountryOriginDescription', 1),
#  ('EngineCycleDescription', 1),
#  ('IsPPlateApproved', 1),
#  ('AverageKM', 1),
#  ('GoodKM', 1),
#  ('GoodRetail', 1),
#  ('PrivateMax', 1),
#  ('NewPrice', 1),
#  ('Branch', 1),
#  ('SaleCategory', 1),
#  ('Sold_Date', 1),
#  ('Make', 0),
#  ('Model', 0),
#  ('MakeCode', 0),
#  ('FamilyCode', 0),
#  ('YearGroup', 0),
#  ('MonthGroup', 0),
#  ('SequenceNum', 0),
#  ('Description', 0),
#  ('CurrentRelease', 0),
#  ('ImportFlag', 0),
#  ('LimitedEdition', 0),
#  ('BodyStyleDescription', 0),
#  ('DriveDescription', 0),
#  ('DriveCode', 0),
#  ('GearTypeDescription', 0),
#  ('GearLocationDescription', 0),
#  ('DoorNum', 0),
#  ('EngineSize', 0),
#  ('EngineDescription', 0),
#  ('Cylinders', 0),
#  ('FuelTypeDescription', 0),
#  ('InductionDescription', 0),
#  ('OptionCategory', 0),
#  ('EngineTypeDescription', 0),
#  ('FuelDeliveryDescription', 0)]

# %% [markdown]
# Wow! Missing values is kind a big deal here! even some columns dont have any information. So what we gonna do here:
#
# 1 - Delete rows where target have missing value. Obviously target neither can have missing nor impute (synthetic) value
#
# 2 - Delete clolumns with missing values more than 10% of number of samples
#
# 3 - Data imputation

# %%
# Now we delete AvgWholesale, AvgRetail, GoodWholesale, GoodRetail, TradeMin, TradeMax, PrivateMax columns as it cant be used in this task
count2, new_df = check_delete_row(train_dat.drop(['AvgWholesale', 'AvgRetail', 'GoodWholesale', 'GoodRetail', 'TradeMin', 'TradeMax', 'PrivateMax'], axis=1))
# Out:
# Number of columns: 123
# Number of rows: 50704
# Total columns have NaN value: 98
# Column with highest NaN: {'AltEngTorqueFrom': 50704, 'NormalChargeMins': 50704, 'QuickChargeMins': 50704, 'NormalChargeVoltage': 50704, 'QuickChargeVoltage': 50704}
# Column with lowest NaN: {'Make': 0, 'Model': 0, 'MakeCode': 0, 'FamilyCode': 0, 'YearGroup': 0}
# Total missing values: 2036246

# %%
# Before further deleting uninformative columns, we nee to see correlation between features and the target
msno.matrix(new_df)
# Out:
# <AxesSubplot:>

# %%
# seems no obvious Missing Not at Random(MNAR) pattern fron matrix above. 
# So we delete columns with more than 80% of number of samples.

count2, new_df = check_delete_row(new_df.dropna(thresh=len(new_df)*0.8, axis=1))
# Out:
# Number of columns: 71
# Number of rows: 50704
# Total columns have NaN value: 46
# Column with highest NaN: {'BadgeDescription': 6605, 'TowingNoBrakes': 5200, 'FuelCombined': 4358, 'WarrantyKM': 2965, 'TowingBrakes': 2944}
# Column with lowest NaN: {'Make': 0, 'Model': 0, 'MakeCode': 0, 'FamilyCode': 0, 'YearGroup': 0}
# Total missing values: 39200

# %%
msno.matrix(new_df)
# Out:
# <AxesSubplot:>

# %%
# Now lets have a look on Sold_Amount on missing value
new_df[new_df['Sold_Amount'].isna()]
# Out:
#          Make      Model MakeCode FamilyCode  YearGroup  MonthGroup  \
# 30025  Holden  Commodore     HOLD    COMMODO       2006           1
# 44059    Ford     Falcon     FORD     FALCON       2005          10
# 47153  Toyota      Camry     TOYO      CAMRY       2008           0
# 50703  Toyota    Corolla     TOYO    COROLLA       2016           0
#
#        SequenceNum                                        Description  \
# 30025            0         VZ MY06 Executive Sedan 4dr. Auto 4sp 3.6i
# 44059           27             BF Futura Sedan 4dr Spts Auto 4sp 4.0i
# 47153            1              ACV40R Altise Sedan 4dr Auto 5sp 2.4i
# 50703            4  ZWE186R Hybrid Hatchback 5dr E-CVT 1.8i/60kW H...
#
#       CurrentRelease ImportFlag LimitedEdition   Series BadgeDescription  \
# 30025              F          L              F       VZ        Executive
# 44059              F          L              F       BF           Futura
# 47153              F          L              F   ACV40R           Altise
# 50703              F          L              F  ZWE186R           Hybrid
#
#       BodyStyleDescription   DriveDescription DriveCode  \
# 30025                Sedan   Rear Wheel Drive       RWD
# 44059                Sedan   Rear Wheel Drive       RWD
# 47153                Sedan  Front Wheel Drive       FWD
# 50703            Hatchback  Front Wheel Drive       FWD
#
#                     GearTypeDescription GearLocationDescription  GearNum  \
# 30025                         Automatic                   Floor      4.0
# 44059                  Sports Automatic                   Floor      4.0
# 47153                         Automatic                   Floor      5.0
# 50703  Constantly Variable Transmission                   Floor      NaN
#
#        DoorNum  EngineSize EngineDescription  Cylinders  \
# 30025        4        3565               3.6          6
# 44059        4        3984               4.0          6
# 47153        4        2362               2.4          4
# 50703        5        1798               1.8          4
#
#          FuelTypeDescription InductionDescription OptionCategory  \
# 30025  Petrol - Unleaded ULP            Aspirated           PASS
# 44059  Petrol - Unleaded ULP            Aspirated           PASS
# 47153  Petrol - Unleaded ULP            Aspirated           PASS
# 50703  Petrol - Unleaded ULP            Aspirated           PASS
#
#       CamDescription EngineTypeDescription  FuelCapacity  \
# 30025  DOHC with VVT                Piston          75.0
# 44059  DOHC with VVT                Piston          68.0
# 47153  DOHC with VVT                Piston          70.0
# 50703  DOHC with VVT     Piston - Electric          45.0
#
#       FuelDeliveryDescription MethodOfDeliveryDescription                VIN  \
# 30025   Multi-Point Injection       Electronic Sequential  6G1ZK52B#6L######
# 44059   Multi-Point Injection       Electronic Sequential  6FPAAAJGSW5*#####
# 47153   Multi-Point Injection       Electronic Sequential  6T153BK400X######
# 50703   Multi-Point Injection       Electronic Sequential  JTNKN3JE40J######
#
#        WheelBase  Height  Length   Width  KerbWeight  Power  PowerRPMTo  \
# 30025     2789.0  1440.0  4876.0  1842.0      1568.0  172.0      6000.0
# 44059     2829.0  1444.0  4916.0  1864.0      1696.0  190.0      5250.0
# 47153     2775.0  1480.0  4815.0  1820.0      1500.0  117.0      5700.0
# 50703        2.0     NaN     NaN     NaN         NaN    NaN         NaN
#
#        Torque  TorqueRPMTo  SeatCapacity BuildCountryOriginDescription  \
# 30025   320.0       2800.0           5.0                     AUSTRALIA
# 44059   383.0       2500.0           5.0                     AUSTRALIA
# 47153   218.0       4000.0           5.0                     AUSTRALIA
# 50703     NaN          NaN           NaN                           NaN
#
#        ValvesCylinder EngineCycleDescription EngineConfigurationDescription  \
# 30025             4.0               4 Stroke                            V60
# 44059             4.0               4 Stroke                        In-line
# 47153             4.0               4 Stroke                        In-line
# 50703             NaN                    NaN                            NaN
#
#       EngineLocation      EngineNum FrontTyreSize RearTyreSize FrontRimDesc  \
# 30025          Front  HBA06 #######    205/65 R15   205/65 R15       15x6.0
# 44059          Front    JGSW5C#####    215/60 R16   215/60 R16       16x6.5
# 47153          Front    2AZ-A######    215/60 R16   215/60 R16       16x6.5
# 50703            NaN            NaN           NaN          NaN          NaN
#
#       RearRimDesc  TowingBrakes  TowingNoBrakes  WarrantyYears  WarrantyKM  \
# 30025      15x6.0        2100.0           500.0            3.0    100000.0
# 44059      16x6.5        2300.0           750.0            3.0    100000.0
# 47153      16x6.5        1200.0           500.0            3.0    100000.0
# 50703         NaN           NaN             NaN            NaN         NaN
#
#        FuelCombined VFactsClass VFactsSegment IsPPlateApproved  AverageKM  \
# 30025          11.0   Passenger         Large                T      275.0
# 44059          10.9   Passenger         Large                T      300.0
# 47153           9.9   Passenger        Medium                T      230.0
# 50703           NaN         NaN           NaN              NaN        NaN
#
#        GoodKM  NewPrice        Colour         Branch SaleCategory  \
# 30025   165.0   33990.0  Quick Silver  Balcatta (WA)       Tender
# 44059   180.0   39175.0       Mercury  Balcatta (WA)       Tender
# 47153   140.0   29990.0         White  Balcatta (WA)       Tender
# 50703     NaN       NaN           NaN            NaN          NaN
#
#                      Sold_Date Compliance_Date  Age_Comp_Months       KM  \
# 30025  2009-04-01 00:00:00.000         02/2006             38.0  70701.0
# 44059  2010-02-04 00:00:00.000         10/2005             52.0  40523.0
# 47153  2010-02-04 00:00:00.000         09/2008             17.0  27217.0
# 50703                      NaN             NaN              NaN      NaN
#
#        Sold_Amount
# 30025          NaN
# 44059          NaN
# 47153          NaN
# 50703          NaN

# %%
# 4 rows have missing value, so we delete it
new_df = new_df[new_df['Sold_Amount'].notna()]

# %%
new_df[new_df['Sold_Amount'].isna()]
# Out:
# Empty DataFrame
# Columns: [Make, Model, MakeCode, FamilyCode, YearGroup, MonthGroup, SequenceNum, Description, CurrentRelease, ImportFlag, LimitedEdition, Series, BadgeDescription, BodyStyleDescription, DriveDescription, DriveCode, GearTypeDescription, GearLocationDescription, GearNum, DoorNum, EngineSize, EngineDescription, Cylinders, FuelTypeDescription, InductionDescription, OptionCategory, CamDescription, EngineTypeDescription, FuelCapacity, FuelDeliveryDescription, MethodOfDeliveryDescription, VIN, WheelBase, Height, Length, Width, KerbWeight, Power, PowerRPMTo, Torque, TorqueRPMTo, SeatCapacity, BuildCountryOriginDescription, ValvesCylinder, EngineCycleDescription, EngineConfigurationDescription, EngineLocation, EngineNum, FrontTyreSize, RearTyreSize, FrontRimDesc, RearRimDesc, TowingBrakes, TowingNoBrakes, WarrantyYears, WarrantyKM, FuelCombined, VFactsClass, VFactsSegment, IsPPlateApproved, AverageKM, GoodKM, NewPrice, Colour, Branch, SaleCategory, Sold_Date, Compliance_Date, Age_Comp_Months, KM, Sold_Amount]
# Index: []

# %% [markdown]
# #### Step 2: Variables similarity

# %%
for i in list(new_df.columns):
    n = new_df[i].unique()
    print(i)
    print(n)
    print(len(n))
# Out:
# Make
# ['Holden' 'Toyota' 'Ford' 'Mazda' 'Mitsubishi' 'Subaru' 'Nissan'
#  'Volkswagen' 'Lexus' 'Land Rover' 'MINI' 'Hyundai' 'Mercedes-Benz'
#  'Dodge' 'Daihatsu' 'Volvo' 'Honda' 'Renault' 'Jeep' 'Peugeot' 'Suzuki'
#  'Isuzu' 'Proton' 'Audi' 'Saab' 'Daewoo' 'Porsche' 'SsangYong'
#  'Great Wall' 'Chrysler' 'Alfa Romeo' 'De Tomaso' 'Citroen' 'Jaguar'
#  'Hummer' 'smart' 'Fiat' 'SKODA' 'Tata' 'Chery' 'Eunos' 'Rover'
#  'Aston Martin' 'Maserati' 'Seat' 'Pontiac' 'Lotus' 'Lamborghini'
#  'Daimler' 'Ferrari' 'Bentley' 'Opel']
# 52
# Model
# ['Commodore' 'RAV4' 'Tarago' 'Camry' 'Falcon' '626' 'Ute' 'Pajero'
#  'Falcon Ute' 'Hiace' 'Aurion' 'Territory' 'Forester' 'Fairlane'
#  'Outlander' 'Navara' 'Epica' 'Magna' 'Corolla' 'Ranger' 'Captiva'
#  'Berlina' 'Statesman' 'Liberty' 'Verada' 'Landcruiser Prado' 'Prius C'
#  'Impreza' 'Transporter' 'Calais' 'Avensis Verso' 'Lancer' 'Echo' 'Rodeo'
#  'Hilux' 'Caprice' 'NX' 'Fiesta' 'Amarok' 'Outback' 'X-Trail' 'CX-9'
#  'Range Rover Sport' 'Triton' 'Hatch' 'Landcruiser' 'Tiida' 'Maxima'
#  'Fairmont' 'i30' 'CLK280' 'Transit' 'Journey' 'Applause' 'Yaris' 'Focus'
#  'Astra' 'Freelander' 'Starwagon' 'RX450h' 'Sonata' 'Cruze' 'Excel'
#  'Charade' 'Laser' 'Patrol' 'CLS350' 'Kluger' 'V50' 'FJ Cruiser' '3'
#  'Odyssey' '86' '6' 'C200 Kompressor' 'i40' 'Mirage' '323' 'Barina' 'Vito'
#  'Santa Fe' 'IS250' 'ix35' 'Challenger' 'Accord' 'Dualis' 'Colorado'
#  'Jetta' 'Terios' 'Express' '2' 'Pulsar' 'GS430' 'iLoad' 'Bora' 'Prius'
#  'Townace' 'Accord Euro' 'Fluence' 'Cherokee' 'Elantra' 'Bravo' 'Adventra'
#  'XC90' 'RX400h' 'Tribute' 'Accent' 'Mondeo' '308' 'Civic' 'Camry Vienta'
#  'Swift' 'APV' 'Courier' '380' 'D-MAX' 'Caddy' 'RX350' 'Golf' 'CR-V'
#  'ML320' 'IS350' 'Jackaroo' 'Persona' 'GS460' 'Gemini' 'CX-7' 'Defender'
#  'Viva' 'LX570' 'Getz' 'Discovery 4' 'Grand Cherokee' 'Explorer'
#  'E350 CDI' 'LT' 'Avalon' 'Sierra' 'A5' '206' 'Lexcen' 'Pathfinder' '900'
#  'Crewman' 'Leganza' 'Vectra' 'Barina Spark' 'Compass' 'Jazz' 'Passat'
#  'Crafter' 'Integra' 'i45' 'Commander' 'ML350' 'Kuga' 'Tucson' 'Vitara'
#  'CT200h' 'Paseo' 'One tonner' 'LS400' 'Festiva' 'City' 'Lanos' '280SE'
#  'Starlet' 'iMax' 'Q7' 'Econovan' 'ML320 CDI' 'Cayenne' 'SX4' 'Discovery'
#  'Frontera' 'Musso' 'Koleos' 'SL500' 'ASX' '4Runner' 'ML350 CDI' 'Megane'
#  'Celica' 'CX-5' 'CLK500' '207' 'Combo' 'C180 Kompressor' 'Lantra'
#  'Escape' 'XV' 'HR-V' 'A4' 'Murano' 'Kizashi' 'E2000' 'A3' 'C180' 'GS450h'
#  'Sprinter' 'V240' 'A6' 'CLK320' 'Grand Voyager' 'Vienta' '156' 'Polo'
#  'Cabrio' 'Satria' 'B2600' 'Rukus' 'Sirion' '9000' 'ML55' 'C250 CDI'
#  'IS200' 'GL320 CDI' 'IS250 C' 'Partner' 'Grand Vitara' 'Longchamp'
#  'BT-50' '9-3' 'PT Cruiser' '9-5' 'E500' 'Xsara' 'Monaro' 'E280' 'Nubira'
#  '200SX' 'Micra' 'Colt' 'Telstar TX5' 'i20' 'Nimbus' 'Viano' 'C4' 'V200'
#  'GS300' 'F150' 'Eunos 30X' 'B180' 'X-Type' 'Jimny' '307' 'MB100' 'Legend'
#  'Prelude' 'MDX' '929' 'Wrangler' 'ML500' 'Terrano II' 'RX-8' 'Caravelle'
#  'ML63' 'C4 Picasso' 'Wagon R+' 'Baleno' 'Rexton' 'Telstar' 'Gen 2'
#  'Beetle' '306' '350Z' 'Discovery 3' '3008' 'Tribeca' 'Clio' 'Touareg'
#  'Zafira' '121' 'Trajet' 'TT' 'Tiguan' 'Ignis' 'H3' 'Supra' 'Kombi' '407'
#  'Trafic' 'Alto' 'Cielo' 'Maverick' 'Countryman' 'Coupe' 'GS250' 'LTD'
#  'LX470' 'XJ6' 'Cressida' 'E320' 'ML270 CDI' 'Freelander 2' 'C36'
#  'S Coupe' 'Meteor' 'S320' 'Apollo' 'S40' 'Boxster' 'Berlingo' 'Kangoo'
#  'Ka' 'BRZ' 'E63' 'S5' 'C200' 'GT' 'Feroza' 'fortwo' 'Ducato' 'Caliber'
#  'Grandeur' 'Taurus' 'ML430' 'Pintara' 'CLK350' '80' 'Q5' 'Patriot'
#  'Freemont' 'Veloster' 'Crossfire' 'Matiz' 'Terracan' 'MB140' 'Master'
#  'Latitude' '370Z' 'Hiace SBV' 'RC' 'Range Rover' 'Liana' 'MR2' 'C250'
#  'Corsair' 'Galant' 'Espero' 'Prius V' 'C5' 'Nitro' 'MX-6' 'S2000' 'Cuore'
#  'A170' 'RX-7' 'E240' 'WRX' 'E230' 'S80' 'E350' 'Urvan' '911' 'RX330'
#  'V70' 'IS F' 'B200' 'WB' 'C30' 'Captur' 'Exa' 'city-coupe'
#  'CLK200 Kompressor' 'X240' 'GTV' 'forfour' 'XC60' 'Superb' 'Tigra' 'S70'
#  '280SEL' 'MPV' 'C320 CDI' 'SL350' 'Brumby' 'Corona' 'Nova' '260E' 'S600'
#  'C3' 'ES300' 'Pajero iO' '19' 'Eos' 'C240' 'MX-5' 'A160' 'F250' '850'
#  'Spacia' 'CR-Z' 'CLC200 Kompressor' 'S63' 'M21' 'SC430'
#  'CLK230 Kompressor' 'QASHQAI' 'Telcoline' 'S60' 'F350' 'Cougar' 'S500'
#  'Cross country' 'Rocky' 'Spider' 'J3' 'Avenger' '500' 'Voyager' 'C70'
#  'S-Type' '760' 'CLK55' '75' 'Liteace' 'ML300 CDI' 'SLK350' 'Ralliart Evo'
#  'Probe' 'Chairman' 'Multivan' 'Camira' 'V40 Cross Country' 'Neon'
#  'Grandis' 'L Series' 'XL-7' 'Suburban' 'Capri' 'Vanette' 'Stavic'
#  'CLK240' 'Cordia' '380SEC' 'LS600hL' '190E' 'R300 CDI' 'DB9' 'Scenic'
#  'A45' 'A1' '3200GT' 'S280' 'Laguna' '911 Carrera' 'S3'
#  'SLK230 Kompressor' 'SLK200 Kompressor' '147' 'Bluebird' 'Quattroporte'
#  'Premacy' 'Skyline' 'C220 CDI' 'CLK430' 'Feroza II' 'C230 Kompressor'
#  'Infiniti' 'E55' 'Actyon Sports' 'XC70' 'V40' '300' 'E1800' '208'
#  'Lacetti' '406' 'Jumbuck' 'Toledo' 'Malibu' 'CC' 'Octavia' 'Savvy'
#  'Kyron' 'E1600' 'Sportswagon' 'E250 CGI' 'Range Rover Evoque' 'Cordoba'
#  '300c' 'Waja' 'CLA200' 'Elantra LaVita' 'Serena' 'Parisienne' 'Tacuma'
#  '1.5i' '740' 'Hilux 4Runner' 'ES350' 'Kalos' '900i' 'Nomad' 'C63'
#  '400SEL' 'CLS500' 'Evora' '230TE' '30X' 'Korando' 'Sebring' 'SLK300'
#  'E2200' 'CRX' 'SLK32' 'Mustang' 'Tiburon' 'S350' 'E200 Kompressor' 'RS5'
#  'Leone' '405' 'E2500' 'X200' 'F100' 'A190' '560SEL' 'E250 CDI' '180E'
#  'Ibiza' 'Carry' '5008' 'S430' '800' 'Raider' 'RX270' 'SLK200' '230E' 'A8'
#  'Wira' 'R350' 'Countach' 'Scirocco' 'GS350' '3000GT' 'B2200' '508'
#  'Crown' 'A150' 'Double 6' 'F430' 'Kingswood' 'XKR' 'E220' 'C200 CGI'
#  'Colorado 7' 'Continental' 'Giulietta' 'Insight' 'Range Rover Vogue'
#  'F20LV' 'Cortina' 'Spyder' 'Move' 'IS300' 'ES300h' 'S8' '100' 'C250 CGI'
#  'Handivan' 'allroad' 'C320' 'Mira' 'E430' '500SL' 'Safari' 'RCZ'
#  'Panamera' 'S350 CDI' 'S420' 'Super V8' 'Alfa 75' 'Esprit' '560SEC'
#  '300ZX' 'E200' 'LS600h' 'Gallardo' 'Calibra' 'DB7']
# 582
# MakeCode
# ['HOLD' 'TOYO' 'FORD' 'MAZD' 'MITS' 'SUBA' 'NISS' 'VOLK' 'LEXU' 'LAND'
#  'MINI' 'HYUN' 'MERC' 'DODG' 'DAIH' 'VOLV' 'HOND' 'RENA' 'JEEP' 'PEUG'
#  'SUZU' 'ISUZ' 'PROT' 'AUDI' 'SAAB' 'DAEW' 'PORS' 'SSAN' 'GREA' 'CHRY'
#  'ALFA' 'DETO' 'CITR' 'JAGU' 'HUMM' 'SMAR' 'FIAT' 'SKOD' 'TATA' 'CHER'
#  'EUNO' 'ROVE' 'ASTO' 'MASE' 'SEAT' 'PONT' 'LOTU' 'LAMB' 'DAIM' 'FERR'
#  'BENT' 'OPEL']
# 52
# FamilyCode
# ['COMMODO' 'RAV4' 'TARAGO' 'CAMRY' 'FALCON' '626' 'UTE' 'PAJERO' 'FALCONU'
#  'HIACE' 'AURION' 'TERRITO' 'FORESTE' 'FAIRLAN' 'OUTLAND' 'NAVARA' 'EPICA'
#  'MAGNA' 'COROLLA' 'RANGER' 'CAPTIVA' 'BERLINA' 'STATESM' 'LIBERTY'
#  'VERADA' 'PRADO' 'PRIUS C' 'IMPREZA' 'TRANSPO' 'CALAIS' 'AVENSIS'
#  'LANCER' 'ECHO' 'RODEO' 'HILUX' 'CAPRICE' 'NX' 'FIESTA' 'AMAROK'
#  'OUTBACK' 'X-TRAIL' 'CX-9' 'RANGE S' 'TRITON' 'HATCH' 'LANDCRU' 'TIIDA'
#  'MAXIMA' 'FAIRMON' 'I30' 'CLK280' 'TRANSIT' 'JOURNEY' 'APPLAUS' 'YARIS'
#  'FOCUS' 'ASTRA' 'FREELAN' 'STARWAG' 'RX450H' 'SONATA' 'CRUZE' 'EXCEL'
#  'CHARADE' 'LASER' 'PATROL' 'CLS350' 'KLUGER' 'V50' 'FJ CRUI' '3'
#  'ODYSSEY' '86' '6' 'C200K' 'I40' 'MIRAGE' '323' 'BARINA' 'VITO' 'SANTA F'
#  'IS250' 'IX35' 'CHALLEN' 'ACCORD' 'DUALIS' 'COLORAD' 'JETTA' 'TERIOS'
#  'EXPRESS' '2' 'PULSAR' 'GS430' 'ILOAD' 'BORA' 'PRIUS' 'TOWNACE' 'ACCORDE'
#  'FLUENCE' 'CHEROKE' 'ELANTRA' 'BRAVO' 'ADVENTR' 'XC90' 'RX400H' 'TRIBUTE'
#  'ACCENT' 'MONDEO' '308' 'CIVIC' 'CAMRYVI' 'SWIFT' 'APV' 'COURIER' '380'
#  'D-MAX' 'CADDY' 'RX350' 'GOLF' 'CRV' 'ML320' 'IS350' 'JACKARO' 'PERSONA'
#  'GS460' 'GEMINI' 'CX-7' 'DEFENDE' 'VIVA' 'LX570' 'GETZ' 'DISCOV4' 'GRAND'
#  'EXPLORE' 'E350 CD' 'LT' 'AVALON' 'SIERRA' 'A5' '206' 'LEXCEN' 'PATHFIN'
#  '900' 'CREWMAN' 'LEGANZA' 'VECTRA' 'BRNSPK' 'COMPASS' 'JAZZ' 'PASSAT'
#  'CRAFTER' 'INTEGRA' 'I45' 'COMMAND' 'ML350' 'KUGA' 'TUCSON' 'VITARA'
#  'CT200H' 'PASEO' 'ONE TON' 'LS400' 'FESTIVA' 'CITY' 'LANOS' '280SE'
#  'STARLET' 'IMAX' 'Q7' 'ECONOVA' 'ML320 C' 'CAYENNE' 'SX4' 'DISCOVE'
#  'FRONTER' 'MUSSO' 'KOLEOS' 'SL500' 'ASX' '4RUNNER' 'ML350 C' 'MEGANE'
#  'CELICA' 'CX-5' 'CLK500' '207' 'COMBO' 'C180K' 'LANTRA' 'ESCAPE' 'XV'
#  'HRV' 'A4' 'MURANO' 'KIZASHI' 'E2000' 'A3' 'C180' 'GS450H' 'SPRINTE'
#  'V240' 'A6' 'CLK320' 'GRAND V' 'VIENTA' '156' 'POLO' 'CABRIO' 'SATRIA'
#  'B2600' 'RUKUS' 'SIRION' '9000' 'ML55' 'C250 CD' 'IS200' 'GL320 C'
#  'IS250 C' 'PARTNER' 'LONGCHA' 'BT-50' '9-3' 'PT CRUI' '9-5' 'E500'
#  'XSARA' 'MONARO' 'E280' 'NUBIRA' '200SX' 'MICRA' 'COLT' 'TX5' 'I20'
#  'NIMBUS' 'VIANO' 'C4' 'V200' 'GS300' 'F150' 'E30X' 'B180' 'X-TYPE'
#  'JIMNY' '307' 'MB100' 'LEGEND' 'PRELUDE' 'MDX' '929' 'WRANGLE' 'ML500'
#  'TERRANO' 'RX8' 'CARAVEL' 'ML63' 'C4 PICA' 'WAGON R' 'BALENO' 'REXTON'
#  'TELSTAR' 'GEN 2' 'BEETLE' '306' '350Z' 'DISCOV3' '3008' 'TRIBECA' 'CLIO'
#  'TOUAREG' 'ZAFIRA' '121' 'TRAJET' 'TT' 'TIGUAN' 'IGNIS' 'H3' 'SUPRA'
#  'KOMBI' '407' 'TRAFIC' 'ALTO' 'CIELO' 'MAVERIC' 'COUNTRY' 'COUPE' 'GS250'
#  'LTD' 'LX470' 'XJ6' 'CRESSID' 'E320' 'ML270' 'FREELA2' 'C36' 'S COUPE'
#  'METEOR' 'S320' 'APOLLO' 'S40' 'BOXSTER' 'BERLING' 'KANGOO' 'KA' 'BRZ'
#  'E63' 'S5' 'C200' 'GT' 'FEROZA' 'FORTWO' 'DUCATO' 'CALIBER' 'GRANDEU'
#  'TAURUS' 'ML430' 'PINTARA' 'CLK350' '80' 'Q5' 'PATRIOT' 'FREEMON'
#  'VELOSTE' 'CROSSFI' 'MATIZ' 'TERRACA' 'MB140' 'MASTER' 'LATITUD' '370Z'
#  'SBV' 'RC' 'RANGE' 'LIANA' 'MR2' 'C250' 'CORSAIR' 'GALANT' 'ESPERO'
#  'PRIUS V' 'C5' 'NITRO' 'MX6' 'S2000' 'CUORE' 'A170' 'RX7' 'E240' 'WRX'
#  'E230' 'S80' 'E350' 'URVAN' '911' 'RX330' 'V70' 'IS F' 'B200' 'WB' 'C30'
#  'CAPTUR' 'EXA' 'CITY-CO' 'CLK200K' 'X240' 'GTV' 'FORFOUR' 'XC60' 'SUPERB'
#  'TIGRA' 'S70' '280SEL' 'MPV' 'C320 CD' 'SL350' 'BRUMBY' 'CORONA' 'NOVA'
#  '260E' 'S600' 'C3' 'ES300' 'IO' '19' 'EOS' 'C240' 'MX5' 'A160' 'F250'
#  '850' 'SPACIA' 'CRZ' 'CLC200K' 'S63' 'M21' 'SC430' 'CLK230K' 'QASHQAI'
#  'TELCOLI' 'S60' 'F350' 'COUGAR' 'S500' 'CROSS C' 'ROCKY' 'SPIDER' 'J3'
#  'AVENGER' '500' 'VOYAGER' 'C70' 'S-TYPE' '760' 'CLK55' '75' 'LITEACE'
#  'ML300 C' 'SLK350' 'R-EVO' 'PROBE' 'CHAIRMA' 'MULTIVA' 'CAMIRA' 'V40CROS'
#  'NEON' 'GRANDIS' 'L SERIE' 'XL-7' 'SUBURBA' 'CAPRI' 'VANETTE' 'STAVIC'
#  'CLK240' 'CORDIA' '380SEC' 'LS600HL' '190E' 'R300 CD' 'DB9' 'SCENIC'
#  'A45' 'A1' '3200GT' 'S280' 'LAGUNA' 'CARRERA' 'S3' 'SLK230K' 'SLK200K'
#  '147' 'BLUEBIR' 'QUATTRO' 'PREMACY' 'SKYLINE' 'C220 CD' 'CLK430'
#  'FEROZA2' 'C230K' 'INFINIT' 'E55' 'ACTSPT' 'XC70' 'V40' '300' 'E1800'
#  '208' 'LACETTI' '406' 'JUMBUCK' 'TOLEDO' 'MALIBU' 'CC' 'OCTAVIA' 'SAVVY'
#  'KYRON' 'E1600' 'SPORTSW' 'E250 CG' 'RANGE E' 'CORDOBA' '300C' 'WAJA'
#  'CLA200' 'ELAVITA' 'SERENA' 'PARISIE' 'TACUMA' '1.5I' '740' 'HILUX4R'
#  'ES350' 'KALOS' '900I' 'NOMAD' 'C63' '400SEL' 'CLS500' 'EVORA' '230TE'
#  '30X' 'KORANDO' 'SEBRING' 'SLK300' 'E2200' 'CRX' 'SLK32' 'MUSTANG'
#  'TIBURON' 'S350' 'E200K' 'RS5' 'LEONE' '405' 'E2500' 'X200' 'F100' 'A190'
#  '560SEL' 'E250 CD' '180E' 'IBIZA' 'CARRY' '5008' 'S430' '800' 'RAIDER'
#  'RX270' 'SLK200' '230E' 'A8' 'WIRA' 'R350' 'COUNTAC' 'SCIROCC' 'GS350'
#  '3000GT' 'B2200' '508' 'CROWN' 'A150' 'DOUBLE6' 'F430' 'KINGSWO' 'XKR'
#  'E220' 'C200 CG' 'COLORA7' 'CONTINE' 'GIULIET' 'INSIGHT' 'RANGE V'
#  'F20LV' 'CORTINA' 'SPYDER' 'MOVE' 'IS300' 'ES300H' 'S8' '100' 'C250 CG'
#  'HANDIVA' 'ALLROAD' 'C320' 'MIRA' 'E430' '500SL' 'SAFARI' 'RCZ' 'PANAMER'
#  'S350 CD' 'S420' 'SUPER V' 'ALFA75' 'ESPRIT' '560SEC' '300ZX' 'E200'
#  'LS600H' 'GALLARD' 'CALIBRA' 'DB7']
# 581
# YearGroup
# [2008 1993 2012 2007 2004 1997 2005 1994 2009 1998 2013 2010 2001 1987
#  2002 2006 1996 2003 2011 1999 1992 2014 2000 1990 1985 1991 1989 1995
#  1988 1978 2015 1983 1980 1982 1981 1984 1986 1976 1975 1968 1979]
# 41
# MonthGroup
# [ 0  7  8 10  1  5  6  9  3 11  2 12  4]
# 13
# SequenceNum
# [  0  41   6  11  38   1   3  10  14  13  58  24   9  22  31   4   8   7
#   21  23  15  43  33  34  17   2   5  16  19  27  18  26  25  46  62  12
#   29  64  28  36  42  20  45  47  54  50  32  81  44  53  35  39  78  55
#   52  73  61  69  92  59  30  37  60  48  40  89  57  84  56  65  63  97
#   49  67  85  77  72  86  91  51  80 111 110  70  88 112 107  82  94  79
#   99  66 108 120  76 113  90  93  75  68  96 105]
# 102
# Description
# ['VE Omega Sedan 4dr. Auto 4sp 3.6i'
#  'VR Executive Wagon 5dr. Auto 4sp 3.8i'
#  'ACA33R MY12 CV Wagon 5dr Man 5sp 4x4 2.4i' ...
#  '313CDI Van Low Roof SWB 4dr Man 5sp 1644kg 2.2DT'
#  '8R MY13 TDI Wagon 5dr S tronic 7sp quattro 2.0DT'
#  'GY1031 MY04 Classic Wagon 5dr Auto 4sp 2.3i']
# 8567
# CurrentRelease
# ['F']
# 1
# ImportFlag
# ['L']
# 1
# LimitedEdition
# ['F' 'T']
# 2
# Series
# ['VE' 'VR' 'ACA33R' ... 'BA11P2' 'RN130R' 'GY1031']
# 1034
# BadgeDescription
# ['Omega' 'Executive' 'CV' 'GLi' 'Altise' 'XT' nan 'Berlina' 'SV6' 'GLX'
#  'XR8' 'Commuter' 'AT-X' 'TX' 'Hybrid' '2.5i' 'Ghia' 'LS' 'Futura' 'ST-X'
#  'XR6' 'CDX' 'Sports' 'Conquest' 'Acclaim' 'XL' '7' 'Xi' 'GXL' 'Forte'
#  'WRX' 'Ascent' 'LX' 'MR' 'Workmate' 'NX200t' 'TDI400' 'ST-L' 'CSi'
#  'Grand Touring' 'TDV6' 'Atara SL' 'Atara S' 'ST' 'Cooper S' 'Ti' 'XLT'
#  'RX' 'X' 'SX' 'Avantgarde' 'ES' '2.5i-S' 'GLX-R' 'CX' 'Standard' 'SXT'
#  'YRS' 'Trend' 'CD' 'i' '50th Anniversary' 'Ascent Sport' 'SS' 'CSi Seca'
#  'Ateva' 'Luxury' 'Limited' 'GX' 'Classique' 'SRi-V' 'SRi' 'S' 'ZR'
#  'Sprint' 'DX' 'Advance' 'RV' 'Levin' 'TX3' 'ST-R' 'SR' 'ST-S' 'KX-S'
#  'Troopcarrier' 'SR5' 'D5' 'Maxx' 'GT' 'Classic' 'Active' 'YR' 'XR6 VCT'
#  'V' 'Astina' 'GLS' 'EcoLPi' 'VX Grande' 'Olympic' '113' 'Elite'
#  'Prestige' 'VTi-L' 'International' '+2' 'TDI' 'KX-R' 'YRX' 'GL' 'Neo'
#  'Sportivo' 'SSS' 'Prodigy' 'LT' 'LXi' '2.0D' 'Grande' 'V5' 'Dynamique'
#  'SX6' 'LE' 'DLX' 'XLS' 'RV6' 'TDI420' 'MX' 'Walk-Thru' 'CC' 'R'
#  'Berlina LX' 'Sportswagon' 'Cruiser' 'TS' 'GA' 'City' 'CX6' 'SVZ'
#  'Platinum' 'SLX' 'SP23' 'Comfortline' 'Sport' 'Marlin' 'V6-L' 'GLXi'
#  'Edge' 'VR-X' '75th Anniversary' 'Touring' '60th Anniversary' 'V8'
#  'Laredo' 'Presara' 'Platinum Edition' 'BlueEFFICIENCY' 'CSX' 'SS V' 'JX'
#  'RS' 'i-Tech' 'RTV' 'G6' 'Evoke' 'GTi' 'VXi' 'Equipe' 'R6' 'VX' 'GTI'
#  'Exceed' 'Ultima' 'Highlander' 'G6E' 'VTi' 'XR6 Turbo' 'XR' '35' 'SRI'
#  'Type R' 'Titanium' 'Thunder' 'GXi' 'LT-R' 'Swing' '103TDI' 'XS' 'V6'
#  'Trio' 'Premium Pack' 'SE' 'Life' '2.5i-L' 'Luxury Sports' 'GL-R' 'FSI'
#  'Maxi' 'Sports Luxury' 'XSE' 'V8i' 'Sahara' 'Bose' 'CL' 'SR5 Limited'
#  'AMG Sports' 'Privilege' 'Elegance' 'Conquest Seca' 'T6' 'Cooper' 'CVX'
#  '118TSI' 'XR8 Magnet' '2.0i-S' 'Activ' 'Attraction' '308CDI' '315CDI'
#  'Super Luxury' 'CXi' '412D' 'Zetec' 'GLE' '77TDI' 'Selespeed' 'Ambiente'
#  '77TSI' 'Liata LXi' 'Heritage' 'Deluxe' 'CDXi' '111CDI' '413CDI' 'TDCi'
#  'Build 1' 'Twin Top' 'VTi-S' 'TI' 'X Series' 'Build 3' 'GTvi' 'AMG'
#  'Lumina' 'SL/X' 'L2' '125TDI' '316CDI' 'ZR6' 'Twin Spark' 'Plus'
#  'GTS 2+2' 'Linear' 'SP25' 'Td5' 'VTR' 'Ultima Seca' '313CDI' 'Extra'
#  'CV8' 'RV Seca' 'Turbo' 'Escape' 'DTi-L' 'LX8' 'Spec R' 'TFSI' 'Ei'
#  'TDI250' 'SRT-8' 'F' 'XSE HDi' 'SR2' 'L' 'SX-R' '40th Anniversary' 'JTS'
#  'VTi-R' 'WRX STI' 'Laredo TSi' 'GSi' 'SV8' 'Atara SX' '115CDI' 'GTS' '5'
#  '108CDI' 'Commonwealth Games Edition' 'LX-R' 'Window' 'Superwagon'
#  'RX270 XVT' 'M Line' 'Si' 'Safety Pack' 'Trio S' 'Expression'
#  '25th Anniversary' 'Shades' 'Esteem' 'Tamworth' 'Ambition' '3.0R-B'
#  'ST HDi' 'JLX' 'John Cooper Works' 'De Ville' '16V' '147TSI' 'Q'
#  'Atara R' '3.6R' 'Extreme' 'Build 2' 'Wildtrak' 'Cabriolet' 'V6 FSI'
#  'Z Series' 'VR' 'Storm' '109CDI' 'FX' 'Td4_e' '250' 'Altitude' 'LS-U'
#  'Altera' 'Trophy' 'SP20' '50' 'XLi' 'Mizuno' '30GV' 'Vi' 'Esprit'
#  'CSi Limited Seca' 'pulse' 'CS' 'JTD' 'CV6' 'XG' 'Ghia +LT & CD' 'ELIII'
#  'F Sport' 'MPS' 'Trekker' 'Trendline' '110TDI' 'CSX Seca' 'Lounge'
#  'Concorde' 'Generation' 'GT220' '2.0i' '2.0R' 'R5 TDI' 'SDX' '+' 'B4'
#  '3.0R' 'TDV8' 'GP Celebration' '90TSI' 'D' 'Luxe' 'H6' 'Snowy' 'Cino'
#  'World Cup' 'Solara' 'JLX Estate' 'Getaway' 'GXE' 'Citivan'
#  'Super Charged' 'RC350' 'Anniversary' 'HSE' 'LS-M' 'Kakadu' 'Premium'
#  'Si6' 'R.S. 200' 'Vacationer' 'SL' '4WS' '132TSI' 'AWD' 'Ti-L' 'Crewvan'
#  'Air' '318CDI' 'STI' 'G6 Limited Edition' 'Cross 8' 'LTZ' 'Microbus' 'SC'
#  'Pacific' 'DX+' 'T' 'Altera LS' 'Genki' 'Alltrack' 'VTi-LN' 'Griffin'
#  'XEi' 'GTL' 'XSE Turbo' 'L Line' 'Grinner' 'RC F' 'SD4' 'Access' 'GTVi'
#  'Vogue' 'G' '125TSI' 'Protege' 'NX300h' 'GS' '113CDI' 'Sport Edition'
#  'GSR' 'Adventure' 'Azura' 'Golden Eagle' 'DX5' 'Sierra' 'Exclusive' 'LXS'
#  'TXE' 'TdV6' 'Roadster' 'Type S' 'Spec S' 'GT2' 'TD4' 'TDI320' '112CDI'
#  'TL' '311CDI' 'Bose Special Edition' 'Coupe' 'Overland' 'Special Edition'
#  'CDTI' 'Twin Cam' 'Aspire' 'TDi' 'Silver Anniversary' 'VR-4' '30G'
#  'V6 TDI' '350' 'J' 'SV' '500' 'Sovereign' 'plus Leather Trim' '208CDI'
#  'Crew' 'Unlimited' 'Club' 'WRX Club Spec 10' 'Tradesman' 'XTE' 'EXE'
#  'Verona' 'Load Runner' 'Evo VI Tommi Makinen' 'WRX Club Spec Evo 5'
#  'Limited Edition' 'T5' 'Sportline' 'Ikon' 'V8SC' '2500 LT' '1000' 'G220'
#  'SPR' 'XR4' 'GSL' 'Spyder' 'SXi' 'EXi' 'GTD' 'R.S. 265' 'L1'
#  'Authentique' 'RX270' 'LS-Terrain' 'Compact' 'TDI340' 'Breeze'
#  '30th Anniversary' 'CS Seca' '130TDI' 'MZR-CD' 'MID'
#  'Advantage Limited Edition' 'Bravo Plus' 's' 'Q45' 'Astina SP' 'Td4' 'T4'
#  'XR5 Turbo' '416CDI' 'Allure' 'CX8' 'Evolution IX' 'S Line' 'Trail'
#  'Metro' '419CDI' 'Match' 'Aero' 'Velocity' 'Le Mans' 'M200' 'Solaire'
#  'Edition' 'Super' 'Classic Extra' 'FI' 'WRX Club Spec' 'Renegade'
#  'Diesel' 'TTR' 'SFX' 'GTV' '309CDI' '2.1-16' 'XE' 'DTi-S' 'T-5' 'Joy'
#  'Designo' 'Luxury Edition' '100th Anniversary' 'Cross 6' 'Vibe' 'GTA'
#  '30V' 'T SE' 'Outback' '312D' 'SE7' 'Jet' 'Track' 'XTR' 'X-Treme'
#  'Linear TiD' 'Cobra' 'MaXX' 'Marquis' 'Olympic Spirit' '155TSI' 'VR6'
#  'V6-24' 'SLX Limited' '4S' 'Sorrento' 'CLX' 'GXV' 'Monza' 'V10 TDI'
#  'Satellite' '2.5i Sports' 'WRX Club Spec Evo 8' 'GLT' 'R/T' 'HEMI' 'SL/E'
#  'Connoisseur SE' 'Super S' 'Monterey' 'Arc' 'S-EDITION' 'Fifty' 'Group X'
#  'Royal' 'BX' 'e' 'Si4' 'F1' 'R36' 'Q Limited' 'GLS Fastback' 'ST-3' 'GT4'
#  'Sports Plus' 'Sports Edition' 'Nugget' 'XS HDi' '2.0' 'Seduction' 'GTC'
#  'Privilege LX' 'Liata GLXi' '2.0i-L' '30S Touring' 'CS 2.3-16' 'C'
#  'Tradie' 'Oasis' 'GT-Line' 'R.S. 250' 'Comfort' '65th Anniversary'
#  'Scout' 'Vector' 'JX Estate' 'M' 'SX 16V' 'WRX Club Spec 9' 'G6E Turbo'
#  'Newport' 'HDi' 'GLSi' 'CSi Limited' 'Limited Sport' 'RZ' 'LRX-1'
#  'Ralliart' 'MS' '3.0R Spec.B' 'R-Design' 'Sportsman' 'QV' 'Vision Series'
#  'Akera' 'Scout Premium' 'Connoisseur' '3.6X' 'Getaway II' '20V'
#  'Super Deluxe' 'LX6' '516CDI' 'di' 'Sportium' 'Exiga' '518CDI' 'Pursuit'
#  'ST170' 'SXR8' 'Design Edition' 'Vantage' '515CDI']
# 649
# BodyStyleDescription
# ['Sedan' 'Wagon' 'Hatchback' 'Utility' 'Bus' 'Cab Chassis' 'Van' 'Coupe'
#  'Softtop' 'Liftback' 'Hardtop' 'Convertible' 'Cabriolet' 'Roadster'
#  'Targa' 'Traytop']
# 16
# DriveDescription
# ['Rear Wheel Drive' '4X4 On Demand' 'Front Wheel Drive' '4X4'
#  'Four Wheel Drive' '4X4 Dual Range' '4X4 Constant']
# 7
# DriveCode
# ['RWD' '4XO' 'FWD' '4X4' '4WD' '4XD' '4XC']
# 7
# GearTypeDescription
# ['Automatic' 'Manual' 'Sports Automatic'
#  'Constantly Variable Transmission' 'Sports Automatic Dual Clutch'
#  'Seq. Manual Auto-Single Clutch' 'Sports Automatic Single Clutch'
#  'Manual Auto-clutch - H Pattern']
# 8
# GearLocationDescription
# ['Floor' 'Dash' 'Column' 'S/Wheel & Floor' 'S/Wheel & Dash'
#  'Steering Wheel' 'S/Wheel & Column']
# 7
# GearNum
# [4. 5. 6. 1. 7. 3. 8. 2. 9.]
# 9
# DoorNum
# [4 5 2 3]
# 4
# EngineSize
# [3565 3791 2362 2995 3984 2497 3564 3200 5408 2438 3456 2498 4942 2359
#  2184 2488 1991 3497 1794 3983 2499 2231 2457 3378 1497 1798 1968 2997
#  1468 1299 3494 1834 2694 1998 1596 3198 2164 3726 2993 2953 2494 3165
#  2982 2477 1598 4461 1797 3498 4164 4089 1975 2996 2999 2402 3604 1589
#  2986 1997 1796 5665 1587 2351 1994 2493 1364 2198 4987 1495 2555  989
#  1597 2400 3956 2156 1999 5667 2972 2835 1840 1389 3828 2188 2500 2354
#  1995 2366 1296 1498 4169 3311 4293 2779 2771 2324 1781 3980 3700 2720
#  3192 2559 1989 1762 1494 2261 2350 1339 2959 5967  993 1590 2606 1896
# 8
# FuelTypeDescription
# ['Petrol - Unleaded ULP' 'Diesel' 'Petrol or LPG (Dual)'
#  'Petrol - Premium ULP' 'LPG only' 'Petrol']
# 6
# InductionDescription
# ['Aspirated' 'Turbo Intercooled' 'Supercharged' 'Twin Turbo Intercooled'
#  'Supercharged Intercooled' 'Turbo' 'Turbo Supercharged Intercooled']
# 7
# OptionCategory
# ['PASS' 'SUV' 'CC' 'BUS' 'VAN' 'UTE']
# 6
# CamDescription
# ['DOHC with VVT' 'Pushrod' 'Double Overhead Cam' 'Overhead Cam' nan
#  'OHC with VVT & Lift' 'OHC with Variable Valve Lift' 'OHC with VVT'
#  'DOHC with VVT & Lift' 'Pushrod with VVT' 'DOHC with Variable Valve Lift']
# 11
# EngineTypeDescription
# ['Piston' 'Piston - Electric' 'Rotary']
# 3
# FuelCapacity
# [ 73.  68.  60.  75.  65.  70.  63.  88.  80.  nan  71.  55.  90. 159.
#   36.  50.  45.  76.  84.  43. 150.  66. 180.  52.  69.  53.  62.  59.
#  145.  77.  42.  93.  67.  64. 125.  89.  72.  74. 116.  86.  44.  46.
#  115. 175.  82.  81.  58.  83.  85.  57.  56.  92. 138.  78.  40.  48.
#   35.  51. 132.  38. 100.  95.  61. 131.  54.  41.  91. 141.  79.  87.
#   47.  94.  37. 110. 105.  33. 130.  96. 144. 101. 113. 126. 120. 152.
#   32.  49.]
# 86
# FuelDeliveryDescription
# ['Multi-Point Injection' 'Direct Injection' 'Carburettor Single'
#  'Direct & Multi-Point Injection' 'Single-Point Injection'
#  'Indirect Injected(Pre-chamber)' 'Carburettor Multiple']
# 7
# MethodOfDeliveryDescription
# ['Electronic Sequential' 'Electronic' 'Mechanical' nan]
# 4
# VIN
# ['6G1EK52B#8L######' '6H8VRK35HPL######' 'JTMBD33V*05######' ...
#  'MRHGD37606P040001' 'WAUZZZ8RXDA######' 'JM0GY1031########']
# 3978
# WheelBase
# [2915. 2822. 2660. 2938. 2950. 2720. 2829. 2610. 2731. 3009. 2780. 3096.
#  2890. 2775. 2842. 2640. 2919. 2670.   nan 3200. 2838. 2700. 2789. 2722.
#  2600. 2921. 2985. 2707. 2788. 2939. 2750. 2675. 2792. 2550. 2620. 3000.
#  2922. 2825. 2900. 2330. 2415. 2370. 3050. 3085. 2489. 3095. 2745. 2630.
#  3220. 2875. 3025. 2790. 2850. 2467. 2980. 2615. 2715. 2635. 2500. 3300.
#  2470. 2648. 2606. 2555. 2465. 2800. 2740. 2525. 2791. 2685. 2510. 2400.
#  2390. 2614. 2970. 2854. 2690. 2830. 2570. 2725. 2760. 2770. 2826. 2960.
#  2605. 3104. 2491. 2730. 2765. 2578. 2420. 2460. 2235. 2793. 2492. 2430.
#  3180. 2625. 2513. 2703. 2705. 2702. 2694. 2957. 2843. 2650. 2947. 2230.
#  2857. 2440. 2735. 3570. 2520. 2265. 2590. 2350. 2682. 2860. 2794. 2820.
#  2490. 2535. 2576. 2455. 2885. 2691. 2574. 3110. 2889. 2874. 4025. 2030.
#  2250. 2750. 4800. 2200. 4600. 2300. 4350. 1850. 1400. 3400. 3150. 1750.
#  6600. 3500. 1200. 3700. 1900. 1950. 3950. 3300. 5200. 5100. 2100. 6300.
#  3100. 1600. 4750. 5500. 3900. 2700. 6000. 4450. 5250. 4725. 4050. 3050.
#  6800. 4900. 1700. 4599. 5300. 2240. 4850. 7500. 3650. 5600. 1500. 5400.
#  7000. 3570. 4150. 4950. 1860. 6200. 3850. 6150. 5750. 2850. 4650. 5700.]
# 84
# SeatCapacity
# [ 5.  8.  2.  7. 14.  3.  4. nan  6. 11. 12.  9. 15.]
# 13
# BuildCountryOriginDescription
# ['AUSTRALIA' 'JAPAN' 'SPAIN' 'SOUTH KOREA' 'SOUTH AFRICA' 'THAILAND'
#  'GERMANY' 'ARGENTINA' 'UNITED KINGDOM' 'MEXICO' 'BELGIUM' 'UNITED STATES'
#  'SWEDEN' 'FRANCE' 'INDONESIA' 'POLAND' 'MALAYSIA' 'AUSTRIA' 'TURKEY'
#  'SLOVAKIA' 'CHINA' 'ITALY' 'INDIA' 'CANADA' 'HUNGARY' 'FINLAND'
#  'NETHERLANDS' 'TAIWAN' 'CZECH REPUBLIC' 'PORTUGAL' 'BRAZIL']
# 31
# ValvesCylinder
# [ 4.  2. nan  3.  5.]
# 5
# EngineCycleDescription
# ['4 Stroke' '2 Stroke']
# 2
# EngineConfigurationDescription
# ['V60' 'V90' 'In-line' nan 'Horizontal' 'V15' 'V' 'V72' 'V75' 'V65'
#  'W72/15']
# 11
# EngineLocation
# ['Front' nan 'Mid-Rear' 'Rear']
# 4
# EngineNum
# ['HBA04 ######' 'VH-######' '2AZ-#######' ... '14V-#####'
#  'M55/01-638#####' 'CGL ######']
# 1522
# FrontTyreSize
# ['225/60 R16' '205/65 R15' '225/65 R17' '205/65 R16' '215/60 R16'
#  '205/55 R15' '245/45 R18' '265/65 R17' '235/45 R17' '185 R14 C 8PR'
#  '235/60 R17' '225/60 R17' '225/50 R17' '215/70 R16' nan '255/70 R16'
#  '245/40 R18' '225/60 R16 SL' '205/60 R16' '195/60 R15' '265/70 R16'
#  '215/70 R15' '235/50 R19' '225/55 R16' '215/60 R16 C' '215/50 R17'
#  '185/60 R15' '225/45 R17' '195/65 R15' '235/55 R17' '185/65 R14'
#  '175/65 R14' '225/70 R15 C' '205/70 R15 C' '235/50 R18' '235/55 R18'
#  '185/55 R15' '245/70 R16' '215/60 R17' '245/50 R20' '255/50 R19'
#  '215/70 R15 C' '235/75 R15' '215/55 R17' '255/65 R17' '205 R16 C 8PR'
#  '205 R16 C 6PR' '195/55 R16' '7.50 R16 LT 8PR' '185/65 R15' '215/65 R16'
#  '225/55 R18' '245/65 R17' '175/70 R13' '215/75 R16 C' '7.50 R16 C 6PR'
#  '185/60 R14' '215/55 R16' '195/80 R15' '205/55 R16' '235/40 R18'
#  '165/75 R13' '225/75 R15 C' '195/80 R14' '235/55 R19' '205/70 R15'
#  '245/70 R17' '195/70 R14' '205/50 R16' '175/65 R15' '205 R16'
#  '185/75 R14' '215/45 R17' '155/65 R13' '205 R16 C' '225/50 R16'
#  '275/65 R17' '245/45 R17' '265/60 R18' '245/55 R19' '265/70 R17'
#  '175/70 R14' '205/80 R16' '195 R14 C' '195/70 R15 C' '235/60 R18'
#  '225/70 R15' '195/65 R14' '215/55 R18' '195 R15 C' '225/55 R17'
#  '195/55 R14' '225/70 R16' '255/70 R15 C' '175 R14 LT 6PR' '235/45 R18'
#  '245/70 R16 RF' '195/75 R14' '175 R14 C' '235/65 R17' '195/60 R16'
#  '225/70 R15 C 8PR' '155/70 R13' '185 R14 C' '205/75 R14' '235/80 R16'
#  '245/70 R16 LT' '215/80 R16' '205/50 R17' '7.50 R16 C 8PR' '255/65 R16'
#  '185 R14' '215/65 R15' '7.50 R16' '195/55 R15' '285/50 R20'
#  '185 R14 LT 8PR' '185/70 R14' '255/50 R20' '225/70 R17' '225/40 R18'
#  '195 R15 C 8PR' '245/40 R19' '235/70 R16' '215/65 R16 C' '235/50 R17'
#  '255/70 R15 LT' '175/80 R14' '205/45 R16' '205/80 R16 RF' '215/65 R15 C'
#  '205/60 R15' '195/70 R14 C 6PR' '235 R15 C' '195 R14 C (613)'
#  '155/70 R14' '225/45 R18' '215/70 R15 C 8PR' '215/45 R18' '235/65 R16'
#  '235/45 R19' '235/60 R16' '195/70 R15' '215/60 R15' '165/70 R13'
#  '195 R14 C 8PR' '275/45 R20' '265/70 R16 LT' '265/70 R15' '285/65 R17'
#  '255/55 R18' '195/50 R15' '275/70 R16' '235/75 R16' '265/40 R21'
#  '205/55 R17' '255/60 R17' '225/75 R15' '195/60 R14' '235/65 R18'
#  '245/65 R17 RF' '195/75 R16' '185/80 R14' '195 R14' '265/75 R16'
#  '225/65 R18' '165/65 R14' '285/50 R18' '215/65 R14' '255/55 R19'
#  '215 R15' '245/35 R19' '215/75 R16' '225/60 R18' '185 R15 C 6PR'
#  '165/70 R14' '295/45 R20' '155 R13' '195/50 R16' '235/85 R16'
#  '245/70 R16 AT' '205 R14' '285/60 R18' '295/40 R20' '195/45 R16'
#  '165/65 R13' '255/60 R18' '205/65 R15 C' '175/60 R14' '205/45 R17'
#  '205/65 R16 C' '155/65 R14' '195/45 R15' '10.00 R15' '195 R14 LT 8PR'
#  '255/65 R17 HT' '175/75 R14' '175/70 R14 C' '225/55 R19' '285/65 R16'
#  '255/70 R15' '255/35 R19' '205 R15' '145/65 R15' '275/55 R17'
#  '155/80 R13' '215/40 R18' '235/70 R17' '225/65 R16' '275/40 R20'
#  '195/70 R15 C 8PR' '235/40 R19' '165 R14 LT 8PR' '205/40 R18'
#  '295/35 R21' '175/75 R16' '265/50 R20' '225/70 R15 LT' '265/75 R16 LT'
#  '245/75 R15 C' '295/45 R19' '225/40 R19' '195/75 R16 C' '195/65 R16'
#  '205/45 R17 RSC' '215/65 R16 XPC' '7.50 R16 8PR' '4.50 R16 6PR'
#  '205 R16 6PR' '255/45 R17' '165/70 R14 C 6PR' '265/75 R15' '255/40 R19'
#  '215/70 R17' '175/55 R15' '225/45 R19' '245/60 R18' '215/50 R16'
#  '245/75 R16' '205/40 R17' '175/65 R13' '215/70 R15 LT' '185/55 R16'
#  '225/60 R15' '215/55 R16 C' '275/45 R21' '195/65 R15 C'
#  '245/75 R16 LT 12PR' '245/45 R19' '265/45 R20' '195/65 R16 C'
#  '235/35 R19' '205/75 R16' '205/50 R15' '215/40 R17' '225/75 R16'
#  '185/65 R13' '245/45 R20' '7.50 R16 6PR' '185/55 R14' '165 R14'
#  '175/50 R15' '165/55 R16' '165 R14 C 8PR' '195 R15 LT 8PR'
#  '205/75 R15 C 8PR' '185/70 R13' '265/35 R19' '185/75 R16 C'
#  '155 R13 C 6PR' '275/45 R19' '185/75 R16' '175/60 R15' '215/45 R16'
#  '175/60 R13' '175/75 R16 C' '225/40 R17' '225/35 R19' '255/40 R18'
#  '215/50 R15' '195 R14 C 6PR' '245/35 R20' '245/75 R17' '275/35 R20'
#  '145/65 R13' '265/35 R20' '215/70 R16 C' '255/45 R20' '255/55 R17'
#  '145/70 R12' '165/60 R15' '255/45 R19' '255/45 R18' '255/35 R20'
#  '235/40 R17' '255/75 R17']
# 296
# RearTyreSize
# ['225/60 R16' '205/65 R15' '225/65 R17' '215/65 R16' '215/60 R16'
#  '205/55 R15' '245/45 R18' '265/65 R17' '235/45 R17' '185 R14 C 8PR'
#  '235/60 R17' '225/60 R17' '225/50 R17' '215/70 R16' nan '255/70 R16'
#  '245/40 R18' '225/60 R16 SL' '205/60 R16' '195/60 R15' '265/70 R16'
#  '215/70 R15' '235/50 R19' '225/55 R16' '215/60 R16 C' '215/50 R17'
#  '185/60 R15' '225/45 R17' '195/65 R15' '235/55 R17' '185/65 R14'
#  '175/65 R14' '225/70 R15 C' '205/70 R15 C' '235/50 R18' '235/55 R18'
#  '185/55 R15' '245/70 R16' '215/60 R17' '245/50 R20' '255/50 R19'
#  '215/70 R15 C' '235/75 R15' '215/55 R17' '255/65 R17' '205 R16 C 8PR'
#  '205 R16 C 6PR' '195/55 R16' '7.50 R16 LT 8PR' '185/65 R15' '245/40 R17'
#  '225/55 R18' '245/65 R17' '175/70 R13' '215/75 R16 C' '7.50 R16 C 6PR'
#  '185/60 R14' '215/55 R16' '195/80 R15' '205/55 R16' '235/40 R18'
#  '165/75 R13' '225/75 R15 C' '195/80 R14' '235/55 R19' '205/70 R15'
#  '245/70 R17' '195/70 R14' '205/50 R16' '175/65 R15' '205 R16'
#  '185/75 R14' '215/45 R17' '155/65 R13' '205 R16 C' '225/50 R16'
#  '275/65 R17' '245/45 R17' '265/60 R18' '245/55 R19' '265/70 R17'
#  '175/70 R14' '205/80 R16' '195 R14 C' '195/70 R15 C' '235/60 R18'
#  '225/70 R15' '195/65 R14' '215/55 R18' '195 R15 C' '225/55 R17'
#  '195/55 R14' '225/70 R16' '255/70 R15 C' '175 R14 8PR LT' '265/75 R16'
#  '235/45 R18' '245/70 R16 RF' '195/75 R14' '175 R14 C' '235/65 R17'
#  '195/60 R16' '225/70 R15 C 8PR' '155/70 R13' '185 R14 C' '205/75 R14'
#  '235/80 R16' '245/70 R16 LT' '215/80 R16' '205/50 R17' '7.50 R16 C 8PR'
#  '255/65 R16' '185 R14' '215/65 R15' '7.50 R16' '195/55 R15' '285/50 R20'
#  '185 R14 LT 8PR' '185/70 R14' '255/50 R20' '225/70 R17' '225/40 R18'
#  '195 R15 C 8PR' '265/35 R18' '245/40 R19' '235/70 R16' '215/65 R16 C'
#  '235/50 R17' '255/70 R15 LT' '175/80 R14' '205/45 R16' '205/80 R16 RF'
#  '215/65 R15 C' '205/60 R15' '195/70 R14 C 6PR' '235 R15 C'
#  '195 R14 C (613)' '155/70 R14' '225/45 R18' '205/65 R16'
#  '215/70 R15 C 8PR' '215/45 R18' '235/65 R16' '235/45 R19' '235/60 R16'
#  '195/70 R15' '215/60 R15' '165/70 R13' '195 R14 C 8PR' '275/45 R20'
#  '265/70 R16 LT' '265/70 R15' '285/65 R17' '255/55 R18' '195/50 R15'
#  '275/70 R16' '235/75 R16' '265/40 R21' '205/55 R17' '255/60 R17'
#  '225/75 R15' '195/60 R14' '235/65 R18' '245/65 R17 RF' '7.50 R16 8PR'
#  '195/75 R16' '185/80 R14' '195 R14' '225/65 R18' '165/65 R14'
#  '285/50 R18' '255/35 R18' '215/65 R14' '255/40 R18' '255/55 R19'
#  '215 R15' '245/35 R19' '215/75 R16' '225/60 R18' '185 R15 C 6PR'
#  '165/70 R14' '295/45 R20' '155 R13' '195/50 R16' '235/85 R16'
#  '245/70 R16 AT' '205 R14 C' '285/60 R18' '295/40 R20' '195/45 R16'
#  '165/65 R13' '255/60 R18' '205/65 R15 C' '175/60 R14' '205/45 R17'
#  '205/65 R16 C' '155/65 R14' '195/45 R15' '10.00 R15' '195 R14 LT 8PR'
#  '255/65 R17 HT' '175/75 R14' '175/70 R14 C' '225/55 R19' '255/70 R15'
#  '285/30 R19' '155 R12 LT 8PR' '205 R15' '175/55 R15' '275/55 R17'
#  '155/80 R13' '215/40 R18' '255/35 R19' '235/70 R17' '225/65 R16'
#  '275/35 R19' '275/40 R20' '265/35 R19' '165 R14 LT 8PR' '205/40 R18'
#  '295/35 R21' '175/75 R16' '225/50 R15' '265/50 R20' '225/70 R15 LT'
#  '265/75 R16 LT' '245/75 R15 C' '295/45 R19' '195/75 R16 C' '195/65 R16'
#  '205/45 R17 RSC' '215/65 R16 XPC' '4.50 R16 6PR' '205 R16 6PR'
#  '255/45 R17' '205/60 R14' '165/70 R14 C 6PR' '315/30 R18' '265/75 R15'
#  '275/40 R19' '215/70 R17' '225/45 R19' '245/60 R18' '215/50 R16'
#  '245/75 R16' '205/40 R17' '175/65 R13' '215/70 R15 LT' '185/55 R16'
#  '225/60 R15' '215/55 R16 C' '275/45 R21' '195/65 R15 C'
#  '245/75 R16 LT 12PR' '245/45 R19' '205/50 R15' '265/45 R20'
#  '195/65 R16 C' '235/35 R19' '195/70 R15 C 8PR' '205/75 R16' '215/40 R17'
#  '245/50 R18' '225/75 R16' '185/65 R13' '245/45 R20' '285/65 R16'
#  '7.50 R16 6PR' '185/55 R14' '275/35 R18' '165 R14' '175/50 R15'
#  '255/45 R20' '165/55 R16' '255/40 R17' '165 R14 C 8PR' '195 R15 LT 8PR'
#  '205/75 R15 C 8PR' '245/35 R18' '185/70 R13' '185/75 R16 C' '295/30 R18'
#  '155 R13 C 6PR' '275/45 R19' '185/75 R16' '175/60 R15' '215/45 R16'
#  '175/60 R13' '175/75 R16 C' '255/35 R17' '295/40 R19' '305/30 R19'
#  '285/35 R18' '255/45 R18' '215/50 R15' '195 R14 C 6PR' '245/35 R20'
#  '245/75 R17' '275/35 R20' '145/65 R13' '265/35 R20' '285/35 R19'
#  '215/70 R16 C' '255/55 R17' '145/70 R12' '235/40 R19' '165/60 R15'
#  '285/40 R19' '275/45 R18' '195/75 R16 C DRW' '255/35 R20' '255/75 R17'
#  '295/30 R19' '255/40 R19']
# 314
# FrontRimDesc
# ['16x7.0' '15x6.0' '17x6.5' '16x6.5' '15x6.5' '18x8.0' '17x7.5' '17x8.0'
#  '14x5.5' '17x7.0' nan '16x6.0' '19x7.0' '15x5.5' '18x7.5' '20x7.5'
#  '19x9.0' '16x5.5' '18x7.0' '13x5.0' '14x5.0' '15x7.0' '19x7.5' '15x5.0'
#  '13x4.0' '17x8.5' '16x5.5F Split' '16x7.5' '18x6.5' '14x6.0' '16x8.0'
#  '13x4.5' '19x7.5J' '14x6.5' '20x8.5' '17x6.0' '18x8.5' '19x8.0' '14x4.5'
#  '20x9.0' '21x9.0' '16x5.0' '18x9.0' '20x10.0' '15x6.0J' '16x8.5' '15x4.0'
# ...
#  'Deep Sea Blue' 'W7 - Taffeta White (H)' 'Harmony (Light Blue)'
#  'Steel Blue' 'Cashmere' 'Harmony' 'French Vanilla' 'Titainium Silver'
#  '774 - Aqua (T)' 'Atomic' '541 - Thulite Red (MB)' 'Pearl' 'Indiana'
#  'Colorado Red' '8S7 - Glacier (T)' 'Quartz Grey' 'Black Silver'
#  'Premium Silver' 'Mercury Silver Metallic' '4N5 - Cashmere (T)'
#  'Sunlight Gold Opal' 'Fantasy' 'QNC - Pearl White (R)' 'Cherry Black'
#  'Silver Ice' '8N6 - Greyish Blue (T)' 'W1 - White Orchid (H)'
#  'Zermatt Silver' 'Silver Crystal' 'Fantale Orange' 'Zest Green'
#  'Leaf Silver' 'Tuscan Red' 'Rose Mist' 'Sleek Silver' 'Stornoway Grey'
#  'Monsoon Grey' 'Pewter' 'Vermillion Fire' 'Morocco Sand Frost'
#  'D31 - Apollo White (R)' 'Dark Amethyst' 'Desert Sand Mtallic'
#  '062 - White Pearl Crystal Shine (T)' 'Winning Blue' 'Copper'
#  'Silver Lightning' 'Phantom Blue' 'Daintree Green' 'Olympic White'
#  'Chill' '590 - Fire Opal (MB)' 'Silver Mica' 'Alaskan Frost' 'Chamois'
#  'Cream' '082 - Glacier White' '8T5 - Tasman (T)' '8K2 - Luna Mist (T)'
#  'Santorini Black' 'Dolphin Grey' '218 - Ecllipse Black (T)'
#  'Laurel Green' 'Storm Blue' '8T6 - Voodoo Blue (T)'
#  'A8 - Graphite Luster (H)' '391 - Horizon Blue (MB)' 'Sierra Red'
#  'Conquer' 'Blue Yellow' '1G0 - Graphite (T)' 'Carbon Steel'
#  'Polar Sea Blue' 'Lucifer' 'Citric Acid' 'Sand Dune' 'White Diamond'
#  'Galaxy Blue ' 'Khaki' 'B51 - Blue Mica Metallic (T)' 'Tiger'
#  'Sapphire Blue' 'Crystal Black Silica Pearl' 'Stardust Silver'
#  '1D2 - Grey Metallic (T)' '1J1 - Lustre (T)'
#  'XNX - Riviera Blue/Diamond Black Roof (R)' 'Moonlight Silver' 'Tan'
#  'Fusion' 'Racing Green' 'Lime Green' 'Pink' 'Java Black'
#  '2JU - Hornet Yellow/White Roof (T)' 'Electric Blue' 'Wired' 'Flare'
#  'Yellow / Blue' 'Perla Nera Black' 'Frontier Green' 'Snow Storm'
#  'Crunch Metallic' 'Panther Mica' '4W7 - Orange Pearl (L)' 'Breeze'
#  'Red Pearl' 'Peacock Green' 'Silver White' 'Garnet' 'Champagne Gold Opal'
#  '798 - Sanidine Beige (MB)' 'Premium White' 'Green Grey' 'Passion Rose'
#  'Creamy White' 'Evo Twilight' 'Volcano Grey Metallic' 'Carlo Blue'
#  'D4S - Storm Black (T)' 'Polynesian Green' 'Cinnamon'
#  'Carbon Flash Black' 'Switch Blade' 'Tanami' 'Glacier' 'Everglade'
#  'Valencia' 'Cove' '2KP - Sandstorm (T)' '1D4 - Silver Metallic (T)'
#  'Black Pearl' 'Velocity Red' 'Roanne Red' 'Monsoon Blue' 'K-Pow Metallic'
#  'Crema' '5A5 - Goldrush (T)' '4R4 - Crystal Gold (T)'
#  'Basalt Black Metallic' '8V8 - Pearl Blue (T)' 'Lilac'
#  '2KB - Titanium/White Roof (T)' 'Paris Whiite'
#  '2KY - Cement/White Roof (T)' '0Q0Q - Pure White (VW)' 'White Black'
#  'Keppel Blue' 'W5 - Brilliant White (H)' 'Casablanca'
#  'Silver Ash - disable' 'Silver Frost' 'Black Sapphire Metallic'
#  'Brilliant Silver' '1D6 - Silver Sky (T)' '214 - Elysium Blue (L)'
#  'Claret' 'Granada' 'Lunar Sky' 'Black Sapphire' 'Royal Crimson'
#  'Inferno Red' 'Monolith Grey Metallic' 'Marine Blue' 'Chilli Red'
#  'Dark Green Mica Metalic' 'Plum' 'Emerald Green' 'Signal Red'
#  'Smokey Eye' 'White Grey' 'Diamond Black' 'MT - Urban Titanium (H)'
#  '8T8 - Aztec Blue (T)' '368 - Flint Grey (MB)' 'Midnight Sky'
#  'Desert Rose' 'Pure Silver' 'Hornet Yellow' 'Shiraz Red' 'Ruby Red'
#  'Merlot Metalilic' 'Gold Champagne' 'Morocco Sand' 'Flame Red'
#  'Metallic Red' 'Grey Mist' 'Black Panther' 'Peacock' '3R7 - Crimson (T)'
#  'Wild Cherry' 'C7P - Mount Fuji Red (T)' 'Military Blue'
#  '8R4 - Blackheath Blue (T)' 'Cirrus White' '8P4 - Dark Blue Metallic (T)'
#  'Red Silver' 'Titanium' 'Ultra Blue' 'Galaxy Grey' 'Blaze' 'Harbour Blue'
#  'Sparkling Black' '6Q7 - Dark Green Mica (T)' 'B50 - Blue Metallic (T)'
#  '8S0 - Ocean Mist (T)' 'Organza.' 'GXA - Metallic Black (R)'
#  '3S0 - Garnet (L)' 'British Racing Green' '4V0 - Amazon (T)' 'Blue Black'
#  'Grey Green' '6T7 - Olive Mica (T)' 'RP - Passion Red (H)'
#  'Graphite Grey Metallic (A)' 'W09 - White (T)' 'KNG - Oyster Grey (R)'
#  'RA - Rallye Red (H)' 'Tungsten' 'Raven Blue' 'Carkey' 'Steel Silver'
#  'S07 - Silver Metallic (T)' 'Burra Pearl' 'Jungle Green'
#  '8W1 - Blue Slate (T)' 'Y7 - Attract Yellow (H) ' 'Charcoal Pearl'
#  'Light Silver Metallic' 'SN - Super Platinum (H)' 'Merlot' 'Alchemy'
#  'Sword Blue' 'Dune' '085 - Sonic Quartz (L)' 'Mint'
#  '369 - Glacier White (R)' 'Thunder' '799 - Diamond White Bright (MB)'
#  'Hazard' 'Ocean Jade' 'Island Blue' '8E8E - Brilliant Silver (SK)'
#  'Alabaster Silver' 'Grand White' 'Black Magic' 'Classic Red'
#  'Blue / Green' 'Kashmir Brown Metallic' 'Midnight Blue' 'Heather Frost'
#  'E8H - Galaxy Blue Silica (T)' 'Celeste Blue' 'SF - Forged Silver (H)'
#  'Laurel Mica' 'Vivid Blue' 'White Gold' 'Silver Gold' 'Bianca White'
#  'Botanica Blue' 'GNE - Star Black (R)' 'Satin White Pearl' 'Mystic'
#  'Cosmo Mica' 'Arctic' 'Red Passion Metallic'
#  '2JV - Voodoo Blue/White Roof (T)' 'Island Grey' 'Kuranda Green'
#  '4U7 - Metallic Silk (L)' 'Argon Silver' 'Flinders Grey'
#  '4E9 - Sandy Taupe (T)' '359 - Tansanite Blue (MB)' 'Plum Blush'
#  '2KD - Jungle/White Roof (T)' 'Salsa Red' '5A7 - Lustre (T)' 'Dawn Blue'
#  'Mustard' 'Cascade Blue' 'Monza Red' 'Winter Grey' 'Blue Velvet'
#  'Sophia White.' 'Satelilite Silver' 'Ironite' 'Radiant Ebony' 'Vitro'
#  'Purple Haze' '3P2 - Bordeaux Mica (T)' 'SM - Polished Metal (H)'
#  '083 - White Nova' 'Aspen Silver' '8U9 - Blue Pearl (T)' 'Vermillion'
#  'Atomic Metallic' 'Turismo' 'Platinum Black Metalic' 'Sunburst'
#  'Toffee Brown' 'LA7N - Limestone Grey' 'Campanella White'
#  '3T0 - Moulin Rouge (T)' 'Timber Green' 'Ardent Red' 'Champagne Silver'
#  'Gold Grey' 'Pacific Blue Metallic' 'Grey Metallic'
#  'XND - Ivory White/Diamond Black Roof (R)' '389 - Glacier White (R)'
#  'Crystal Grey' 'LO - Deep Ocean Blue (H)' 'Regal Blue' 'Cool Blue'
#  'Diablo Red' 'Fawn' 'Silver (Do Not Use Disabled)'
#  'HXA - Mineral Beige (R)' 'Iris Blue' 'KXC - Ultra Silver (R)'
#  'Raven Black' 'Meteor Grey' 'Black Grey' 'NNJ - Dynamic Red (R)'
#  'Daytona Grey' 'Apple Green' 'Inca Green Quartz Silver' 'Shark Blue'
#  'B66 - Eclipse Grey (R)' 'Calypso Red' 'Beige White'
#  '583 - Champagne Metallic (T)' 'Misty Rose' 'Masai Mica' 'Black Emerald'
#  'W6 - Premium White (H)' 'Red  White' 'Northern Blue' 'Denim Blue'
#  'Havanna Metallic' '6V4 – Deep Green MC (T)' '078 - Quartz White (L)'
#  'Pepper Grey' 'Green Black' '761 - Polar Silver (MB)' 'Maranello Red'
#  'Masai Red' 'LM - Morpho Blue (H)' 'Metro' 'Regal Peacock'
#  '3H4 - Red Mica (T)' 'Silverstone' 'A61 - Crimson Red' 'Chino'
#  'Dark Grape' 'Velvet Red' 'Dark Micastone' 'Morrocan Blue' 'Glow'
#  'Powder White' 'Grey/ Red' 'Summit White'
#  '1C6 - Dark Grey Mica Metallic (T)' 'Green Timber' 'Panama Blue'
#  '2KQ - Military Blue/White Roof (T)' 'Dark Silver' 'Flinders Red'
#  'Burnt Orange' 'Cobalt Blue' 'Pyrenees Black' 'Obsession' 'Blue Mist'
#  'Windsor Blue' 'Aurora Gold' '5A6 - Sting (T)' 'Ibis White' 'Oyster'
#  'Moody Blue' '8Q1 - Rhapsody (T)' 'Wildfire Orange'
#  'Anthracite Grey Metallic' 'Silver Essence' 'Stone White' 'Rosso Corsa'
#  'Atlas Grey' 'Dover White' 'Boston Black' '723 - Cubanite Silver (MB)'
#  'Opal Green' 'Dash' 'Brass' 'K1X – White Liquid (T)' 'Flint Mica'
#  'Monterey' 'Bright Silver' 'Envy' 'Hip Hop Red' 'Night Blue Metallic'
#  'Red White' 'Black Opal Metallic' 'Olive Drab' 'KNG - Lunar Grey (R)'
#  'Travertine Biege' 'Sport Yellow' 'Satin Red' 'Sky Blue Metallic'
#  'Shimmer' 'Light Green Pearl' 'Orca Black' 'Effect Grey' 'Turbine Grey'
#  'Ipanema Sand' 'Bone' 'Viper' 'Bluestone Metallic' 'Empire Blue'
#  'Splash White' '8W1 - Blue Mist (T)' 'SA - Modern Steel (H)' 'Blue Flame'
#  'Brown Red' 'Pale Blue' 'Sahara Beige' 'Crystal Mint' 'Fox Fire'
#  '1J1 - Green Potion (T)' 'ST - Storm Silver (H)' 'Amazon Green'
#  '494 - Terra Bronze Metallic' 'Midnight Black' 'Champagne Pearl'
#  'White Silver' 'Morello' 'Flame Blue' 'Archon Bronze' 'Lugano Green'
#  '030 - Goldgelb Pearl (MB)' 'Condor Grey' 'Ink Blue'
#  'Deep Blue Pearl Effect' 'RPB - Majorelle Blue (R)' 'Ebony Black' 'Tango'
#  'Kingfisher Blue' 'LV - Vivid Sky Blue (H)' 'Opel' 'Mauve'
#  'Madeira Pearl' 'Heather Green' 'Spruce Green' 'Pannacotta' 'Storm Grey.'
#  'Sophia White' 'Plasma Blue' 'Metropolis Blue' 'Mica Midnight Black'
#  'GNA - Deep Black (R)' 'Ironbark' 'Clean Blue' 'G8 - Green Opal (H)'
#  'Aero Blue Metallic (A)' 'Performance Blue' 'Pistachio' 'Imperial Blonde'
#  'Brown Beige' 'Golden Sand' 'Newport Blue' '6S9 - Jade Green (T)'
#  'Delphin Grey' 'Topaz Gold']
# 906
# Branch
# ['Perth (WA)' 'Belmore (NSW)' 'Sunshine (VIC)' 'Hobart (TAS)'
#  'Adelaide (SA)' 'Geebung (QLD)' 'Balcatta (WA)' 'Canberra (ACT)'
#  'Tullamarine (VIC)' 'Townsville (QLD)' 'Darwin (NT)' 'Dubbo (NSW)'
#  'Newcastle (NSW)' 'Tamworth (NSW)' 'Rundles Wagga Wagga (NSW)'
#  'Welshpool (WA)' 'Alice Springs (NT)' 'Albany (WA)']
# 18
# SaleCategory
# ['Auction' 'Dealer Only Auction' 'Special Fixed Price' 'Fixed Price'
#  'Tender' 'Pickles Online']
# 6
# Sold_Date
# ['2015-11-03 00:00:00.000' '2000-10-18 00:00:00.000'
#  '2014-02-05 00:00:00.000' ... '2007-07-27 00:00:00.000'
#  '2003-07-20 00:00:00.000' '2015-09-27 00:00:00.000']
# 4747
# Compliance_Date
# ['02/2008' '08/1993' '10/2012' '01/2007' '11/2004' '12/1997' '03/2005'
#  '06/1993' '09/1994' '08/2009' '09/2008' '03/2004' '03/1998' '12/2004'
#  '11/2013' '09/2007' '12/2009' '11/2010' '06/2013' '02/2001' '05/2007'
#  '12/1987' '11/2002' '06/2007' '07/2010' '02/2009' '09/2005' '05/2002'
#  '12/2006' '07/1994' '01/2005' '12/1996' '04/2010' '03/2012' '06/2003'
#  '01/2001' '08/2011' '10/2011' '08/1998' '12/1998' '01/2009' '02/1999'
#  '07/2009' '08/1997' '05/2010' '11/1998' '01/2002' '03/2011' '06/2006'
#  '10/2001' '10/1996' '04/1992' '05/1997' '04/2002' '07/2002' '03/2009'
#  '06/2005' '12/2001' '10/2010' '03/2014' '12/2014' '02/2005' '09/2011'
#  '05/2013' '12/2013' '04/2001' '11/2000' '06/2004' '04/2011' '07/2012'
#  '11/2006' '09/1997' '02/2013' '03/2013' '07/1999' '08/2006' '06/2010'
#  '04/2006' '08/2010' '12/2000' '09/1998' '03/2006' '01/2004' '11/2005'
#  '05/2011' '12/1994' '03/2007' '02/2002' '11/2012' '03/1990' '08/1985'
#  '03/2003' '10/2007' '05/2009' '06/2008' '01/2008' '06/2009' '03/1999'
#  '09/2009' '01/2010' '02/1996' '12/2008' '07/2005' '10/2008' '08/2001'
#  '09/2006' '07/2013' '01/2012' '10/2005' '05/1991' '09/2003' '05/2008'
#  '10/2013' '11/2011' '01/1999' '08/2013' '10/2006' '02/2003' '05/2003'
#  '08/2005' '05/2006' '02/2011' '01/2014' '02/1997' '02/2000' '05/2001'
#  '06/2012' '08/2002' '05/2000' '10/1997' '08/1999' '07/2004' '09/1991'
#  '08/2004' '09/2014' '07/1998' '06/1998' '07/1989' '02/2006' '10/2014'
#  '12/2012' '12/1992' '04/2008' '01/2013' '03/1997' '06/2000' '02/2012'
#  '01/1998' '04/2013' '04/2003' '04/2012' '03/2000' '03/2002' '09/2000'
#  '05/1998' '07/1996' '03/2010' '02/2004' '12/2005' '06/1999' '02/2010'
#  2.020e+02 1.900e+02 2.050e+02 2.000e+02 2.460e+02 1.990e+02 4.220e+02
#  1.920e+02 2.160e+02 3.280e+02 1.850e+02 1.930e+02 3.240e+02 2.780e+02
#  2.290e+02 1.530e+02 3.370e+02 2.110e+02 2.480e+02 1.670e+02 1.780e+02
#  2.470e+02 2.640e+02 4.390e+02 2.620e+02 2.420e+02 2.060e+02 2.680e+02
#  2.580e+02 1.570e+02 2.090e+02 2.860e+02 1.720e+02 3.130e+02 2.100e+02
#  2.270e+02 2.910e+02 2.660e+02 4.460e+02 2.500e+02 1.880e+02 2.530e+02
#  2.450e+02 2.030e+02 2.010e+02 3.740e+02 2.150e+02 2.610e+02 2.960e+02
#  2.240e+02 2.120e+02 2.260e+02 2.730e+02 0.000e+00 2.140e+02 1.279e+03
#  2.630e+02 2.190e+02 1.870e+02 2.440e+02 2.900e+02 3.430e+02 2.330e+02
#  2.740e+02 2.760e+02 2.820e+02 2.710e+02 3.190e+02]
# 278
# KM
# [227878. 153091.  27374. ...  37778. 100184.  95183.]
# 43677
# Sold_Amount
# [ 2000.    6800.   22900.   ... 16240.   45800.   13199.99]
# 2715

# %%
# After went through the data there are 4 columns we can delete Make_Code.
# Family_Code (similar), CurrentRelease & ImportFlag (only have single value)
count2, new_df = check_delete_row(new_df.drop(['MakeCode', 'FamilyCode', 'CurrentRelease', 'ImportFlag'], axis=1))
# Out:
# Number of columns: 67
# Number of rows: 50700
# Total columns have NaN value: 35
# Column with highest NaN: {'BadgeDescription': 6605, 'TowingNoBrakes': 5199, 'FuelCombined': 4357, 'WarrantyKM': 2964, 'TowingBrakes': 2943}
# Column with lowest NaN: {'Make': 0, 'Model': 0, 'YearGroup': 0, 'MonthGroup': 0, 'SequenceNum': 0}
# Total missing values: 39158

# %% [markdown]
# #### Step 3: Data imputation and transformation

# %%
new_df[new_df.columns[new_df.isna().any()]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50700 entries, 0 to 50702
# Data columns (total 35 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Series                          49849 non-null  object
#  1   BadgeDescription                44095 non-null  object
#  2   CamDescription                  50482 non-null  object
#  3   FuelCapacity                    49888 non-null  float64
#  4   MethodOfDeliveryDescription     50678 non-null  object
#  5   VIN                             50122 non-null  object
#  6   WheelBase                       50557 non-null  float64
#  7   Height                          49982 non-null  float64
#  8   Length                          50042 non-null  float64
#  9   Width                           50044 non-null  float64
#  10  KerbWeight                      49167 non-null  float64
#  11  Power                           50589 non-null  float64
#  12  PowerRPMTo                      50563 non-null  float64
#  13  Torque                          50428 non-null  float64
#  14  TorqueRPMTo                     50393 non-null  float64
#  15  SeatCapacity                    50664 non-null  float64
#  16  ValvesCylinder                  50191 non-null  float64
#  17  EngineConfigurationDescription  48841 non-null  object
#  18  EngineLocation                  50688 non-null  object
#  19  EngineNum                       49897 non-null  object
#  20  FrontTyreSize                   49797 non-null  object
#  21  RearTyreSize                    49797 non-null  object
#  22  FrontRimDesc                    49975 non-null  object
#  23  RearRimDesc                     49975 non-null  object
#  24  TowingBrakes                    47757 non-null  float64
#  25  TowingNoBrakes                  45501 non-null  float64
#  26  WarrantyYears                   48087 non-null  float64
#  27  WarrantyKM                      47736 non-null  float64
#  28  FuelCombined                    46343 non-null  float64
#  29  VFactsClass                     50273 non-null  object
#  30  VFactsSegment                   50273 non-null  object
#  31  Colour                          50657 non-null  object
#  32  Compliance_Date                 50656 non-null  object
#  33  Age_Comp_Months                 50656 non-null  float64
#  34  KM                              50699 non-null  float64
# dtypes: float64(19), object(16)
# memory usage: 13.9+ MB

# %%
# The missing values columns have float and objet types, so to make it simple use 'most frequent' type data imputation
imputer = SimpleImputer(strategy='most_frequent')
new_df.iloc[:,:] = imputer.fit_transform(new_df)

# %%
# list of columns with object datatype
obj_list = list(new_df.select_dtypes('object').columns)

# %%
# label encoding and save encoding for test data

le = LabelEncoder()
#trained_le = le.fit(new_df)
new_df[obj_list] = new_df[obj_list].astype(str)
new_df[obj_list] = new_df[obj_list].apply(le.fit_transform)
dump(le, open('encoder.pkl', 'wb'))

# %%
x_train = new_df[new_df.columns.drop('Sold_Amount')].to_numpy()
y_train = new_df['Sold_Amount'].to_numpy()

# %% [markdown]
# ### Randon Forest regression

# %% [markdown]
# #### Hyperparameter tuning
#
# Resource: https://www.kaggle.com/code/arjunprasadsarkhel/simple-random-forest-with-hyperparameter-tuning
#
# #### Warning! this process may take more than 10 minutes depend on your machine, avoid this step if you just want to see the results

# %%
n_estimators = [5,20,50,100, 300, 500] # number of trees in the random forest
max_features = ['auto', 'sqrt'] # number of features in consideration at every split
max_depth = [int(x) for x in np.linspace(10, 120, num = 12)] # maximum number of levels allowed in each decision tree
min_samples_split = [2, 6, 10, 50] # minimum sample number to split a node
min_samples_leaf = [1, 3, 4, 10] # minimum sample number that can be stored in a leaf node
bootstrap = [True, False] # method used to sample data points

random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# %%
regr = RandomForestRegressor()
#regr.fit(x_train, y_train)

# %%
from sklearn.model_selection import RandomizedSearchCV
rf_random = RandomizedSearchCV(estimator = regr, param_distributions = random_grid,
               n_iter = 100, cv = 5, verbose=2, random_state=35, n_jobs = -1)

# %%
## This process will take 10 minutes or longer!!!!!

rf_random.fit(x_train, y_train)

# %%
print ('Random grid: ', random_grid, '\n')
# print the best parameters
print ('Best Parameters: ', rf_random.best_params_, ' \n')

# %% [markdown]
# #### Training

# %%
scaler = Pipeline(steps=[('scaler', StandardScaler())])
#randmf = RandomForestRegressor(n_estimators = 100, min_samples_split = 2, min_samples_leaf= 1, max_features = 'auto', max_depth= 120, bootstrap=True)
model = Pipeline(steps=([('RFregression', RandomForestRegressor(n_estimators = 100, 
                                                                                    min_samples_split = 10, min_samples_leaf= 1, max_features = 'auto', 
                                                                                    max_depth= 80, bootstrap=True))]))
#randmf = RandomForestRegressor(n_estimators = 50, min_samples_split = 2, min_samples_leaf= 3, max_features = 'auto', max_depth= 60, bootstrap=True)
model.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('RFregression',
#                  RandomForestRegressor(max_depth=80, min_samples_split=10))])

# %%
pred = model.predict(x_train)
accuracy_train = model.score(x_train, y_train)
score_train = explained_variance_score(y_train, pred)
r2_train = r2_score(y_train, pred)
print(accuracy_train)
print(score_train)
print(r2_train)
# Out:
# 0.9697749164400346
# 0.9697782267147026
# 0.9697749164400346

# %%
#dump(randmf, open('rf_model.pkl', 'wb')) #save model

# %% [markdown]
# ### Record experiment and save model to mlflow

# %%
model_name = "clf-model"

with mlflow.start_run() as run:
    run_num = run.info.run_id
    model_uri = "runs:/{run_id}/{artifact_path}".format(run_id=run_num, artifact_path=model_name)

    mlflow.log_metric('accuracy_train', accuracy_train)
    mlflow.log_metric('explained_variance_score', score_train)
    mlflow.log_metric('r2', r2_train)
    mlflow.sklearn.log_model(model, model_name)
  #mlflow.sklearn.save_model(model, "clf-model")

    model_details = mlflow.register_model(
        model_uri=model_uri,
        name=model_name)
# Out:
# Registered model 'clf-model' already exists. Creating a new version of this model...
# 2022/10/22 18:16:35 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: clf-model, version 4
# Created version '4' of model 'clf-model'.

# %%
model_version_infos = client.search_model_versions("name = '%s'" % model_name)
new_model_version = max([model_version_info.version for model_version_info in model_version_infos])

# %%
from mlflow.entities.model_registry.model_version_status import ModelVersionStatus

def wait_model_transition(model_name, model_version, stage):
  client = MlflowClient()
  for _ in range(10):
    model_version_details = client.get_model_version(
      name=model_name,
      version=model_version,
    )
    status = ModelVersionStatus.from_string(model_version_details.status)
    print("Model status: %s" % ModelVersionStatus.to_string(status))
    if status == ModelVersionStatus.READY:
      client.transition_model_version_stage(
          name=model_name,
          version=model_version,
          stage=stage,
        )
      break
    time.sleep(1)

# %%
try:
  wait_model_transition(model_name, int(new_model_version)-1, "None")
except:
  pass

wait_model_transition(model_name, new_model_version, "Staging")
# Out:
# Model status: READY
# Model status: READY

# %%
new_model_version
# Out:
# '4'

# %%
client.update_model_version(
  name=model_name,
  version=new_model_version,
  description="This model is a random forest regression for Datium car auto sale data."
)
# Out:
# <ModelVersion: creation_timestamp=1666433795128, current_stage='Staging', description='This model is a random forest regression for Datium car auto sale data.', last_updated_timestamp=1666433803392, name='clf-model', run_id='3050c22bfa684c03a17b07ee6bff7588', run_link='', source='./artifacts/1/3050c22bfa684c03a17b07ee6bff7588/artifacts/clf-model', status='READY', status_message='', tags={}, user_id='', version='4'>

# %%
import mlflow.pyfunc

model_name = "clf-model"
stage = 'Staging'

## download model
loaded_model = mlflow.pyfunc.load_model(
    model_uri=f"models:/{model_name}/{stage}"
)

# %% [markdown]
# ### Inferencing with test data

# %%
col_list = list(new_df.columns) # get column list from train data

# %%
new_test = test_dat[col_list] # select feature columns

# %%
# load model and encoder

encoder = load(open('encoder.pkl', 'rb'))

# %%
new_test.isna().any()
# Out:
# Make               False
# Model              False
# YearGroup          False
# MonthGroup         False
# SequenceNum        False
#                    ...
# Sold_Date          False
# Compliance_Date     True
# Age_Comp_Months     True
# KM                  True
# Sold_Amount        False
# Length: 67, dtype: bool

# %%
new_test.iloc[:,:] = imputer.fit_transform(new_test)
# Out:
# C:\Users\faizm\.conda\envs\datium\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)

# %%
new_test[obj_list] = new_test[obj_list].astype(str)
new_test[obj_list] = new_test[obj_list].apply(encoder.fit_transform)
# Out:
# C:\Users\faizm\.conda\envs\datium\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
x_test = new_test[new_test.columns.drop('Sold_Amount')].to_numpy()
y_test = new_test['Sold_Amount'].to_numpy()

# %%
predicted_probs = loaded_model.predict(x_test)
predicted_probs
# Out:
# array([17649.41660542, 55024.07158968, 11164.83069047, ...,
#        19868.57592211, 12262.33214675, 13224.85774496])

# %%
#yhat = rfmodel.predict(x_test)
# evaluate accuracy
acc = explained_variance_score(y_test, predicted_probs)
r2 = r2_score(y_test, predicted_probs)
print('Test Accuracy:', acc)
print('R2 Score:', r2)
# Out:
# Test Accuracy: 0.8703349824987556
# R2 Score: 0.8693015522508301
